# %%
from functools import partial
import json
import math
import re

import numexpr
import numpy as np
import pandas as pd

# %% [markdown]
# ### Known issues
# * Raiseskeleton life is high compared to game, but matches pet calculator
# * Claygolem AR is 20 lower than game. Much lower than pet calculator, which uses character level.

# %%
N_CALC_FIELDS = 4
N_PARAMS = 8
LVL_BREAKPOINTS = [(0, 1), (1, 8), (8, 16), (16, 22), (22, 28), (28, None)]

# %% [markdown]
# # Read game data JSON
# Extracted from patch_d2.mpq and processed by mpq_data_parser
#
# * Corrected Firewall EDmgSymPerCalc, added )
# * Adjusted Raise Skeleton descline, removed outer (), was breaking calc regexes
# * Adjusted Zeal descline, removed outer (), was breaking calc regexes

# %%
with open('../mpq_data_parser/data/d2_skill_data.json') as f:
    skill_details = json.load(f)['skillDetails']

# %% [markdown]
# # Generate descriptions from lookup

# %% [markdown]
# ## Define calculators

# %%
def calculate_damage(skill, skill_levels, lvl, initial_damage_key, damage_per_level_key_root, synergy_key, missile_num=None):
    if missile_num:
        skill = skill[f'missile{missile_num}']
    
    synergy_bonus = calculate_skill_value(skill.get(synergy_key), skill, skill_levels, lvl) or 0
    synergy_multiplier = (100 + synergy_bonus) / 100
    
    damage_per_level_values = (
        [skill[initial_damage_key]] + [skill.get(f'{damage_per_level_key_root}{i}', 0) for i in range(1, 6)]
    )
    damage = 0
    for (lower, upper), damage_per_level in zip(LVL_BREAKPOINTS, damage_per_level_values):
        if lvl <= lower:
            break
        lvl_for_band = min(upper, lvl) if upper is not None else lvl
        damage += (lvl_for_band - lower) * damage_per_level
    hitshift = skill.get('hitShift', 0)
    return damage * synergy_multiplier * 2 ** (hitshift - 8)

calculate_physical_damage_min = partial(
    calculate_damage,
    initial_damage_key='minDam',
    damage_per_level_key_root='minLevDam',
    synergy_key='dmgSymPerCalc',
)
calculate_physical_damage_max = partial(
    calculate_damage,
    initial_damage_key='maxDam',
    damage_per_level_key_root='maxLevDam',
    synergy_key='dmgSymPerCalc',
)
calculate_elemental_damage_min = partial(
    calculate_damage,
    initial_damage_key='eMin',
    damage_per_level_key_root='eMinLev',
    synergy_key='eDmgSymPerCalc',
)
calculate_elemental_damage_max = partial(
    calculate_damage,
    initial_damage_key='eMax',
    damage_per_level_key_root='eMaxLev',
    synergy_key='eDmgSymPerCalc',
)

# %%
def calculate_mana_cost_per_second(skill, skill_levels, lvl):
    return calculate_mana_cost(skill, skill_levels, lvl) * FRAMES_PER_SECOND / 2

def calculate_mana_cost(skill, skill_levels, lvl, multiplier=None):
    mana, lvl_mana, mana_shift = skill['mana'], skill.get('lvlMana', 0), skill['manaShift']
    cost = (mana + lvl_mana * (lvl - 1)) * 2 ** (mana_shift - 8)
    if multiplier:
        cost *= multiplier
    return max(cost, skill.get('minMana', 0))

def floor(x, precision=None):
    if precision is None:
        return math.floor(x)
    floored = math.floor(precision * x) / precision
    return int_if_no_decimals(floored)

def int_if_no_decimals(x):
    return int(x) if not x % 1 else x

def calculate_to_hit(skill, skill_levels, lvl):
    to_hit_expression = skill.get('toHitCalc')
    if to_hit_expression:
        return calculate_skill_value(to_hit_expression, skill, skill_levels, lvl)

    return skill.get('toHit', 0) + skill.get('levToHit', 0) * (lvl - 1)

def calculate_length(skill, skill_levels, lvl):
    synergy_length_bonus = calculate_skill_value(skill.get('eLenSymPerCalc'), skill, skill_levels, lvl) or 0
    synergy_length_multiplier = (100 + synergy_length_bonus) / 100

    length_per_level_values = (
        [skill['eLen']] + [skill.get(f'eLevLen{i}', 0) for i in range(1, 4)]
    )
    length = 0
    for (lower, upper), length_per_level in zip(LVL_BREAKPOINTS[:3], length_per_level_values):
        if lvl <= lower:
            break
        lvl_for_band = min(upper, lvl) if upper is not None else lvl
        length += (lvl_for_band - lower) * length_per_level

    return length * synergy_length_multiplier

def calculate_mXeo(skill, skill_levels, lvl, missile_num):
    return 256 * calculate_elemental_damage_min(skill, skill_levels, lvl, missile_num=missile_num)

def calculate_mXey(skill, skill_levels, lvl, missile_num):
    return 256 * calculate_elemental_damage_max(skill, skill_levels, lvl, missile_num=missile_num)

def create_linear_calculator(param_key_a, param_key_b):
    def calculator(skill, skill_levels, lvl):
        a = skill['params'].get(param_key_a, 0)
        b = skill['params'].get(param_key_b, 0)
        return a + b * (lvl - 1)
    return calculator

def create_diminishing_calculator(param_key_a, param_key_b):
    def calculator(skill, skill_levels, lvl):
        a = skill['params'].get(param_key_a, 0)
        b = skill['params'].get(param_key_b, 0)
        return floor(a + ((110 * lvl) * (b - a)) / (100 * (lvl + 6)))
    return calculator

def create_calculator_on_calc_field(calc_field):
    def calculator(skill, skill_levels, lvl):
        return calculate_skill_value(skill['calcs'][calc_field], skill, skill_levels, lvl)
    return calculator

def create_mastery_calculator(mastery_key):
    def calculator(skill, skill_levels, lvl):
        return calculate_skill_value(skill['mastery'][mastery_key], skill, skill_levels, lvl)
    return calculator

def _get_param(skill, skill_levels, lvl, param_number):
    return skill['params'][f'par{param_number}']

# %%
def calculate_skill_value(calc_expression, skill, skill_levels, lvl):
    if calc_expression is None:
        return None
    if isinstance(calc_expression, int):
        return calc_expression
    if not calc_expression.strip():
        return None
    
    calc_expression = _fill_other_skill_levels(str(calc_expression), skill_levels)
    calc_expression = _evaluate_sklvl_calcs(calc_expression, skill, skill_levels, lvl)
    calc_expression = _evaluate_other_entity_calcs(calc_expression, skill, skill_levels, lvl)
    calc_expression = _evaluate_calcs(calc_expression, skill, skill_levels, lvl)
    calc_expression = _evaluate_mins(calc_expression)
    calc_expression = _fill_if_thens(calc_expression)

    calc = numexpr.evaluate(calc_expression).item()
    return calc

def _fill_other_skill_levels(calc_expression, skill_levels):
    return re.sub(
        pattern=r"skill\('((?:\w|\s)+)'.(?:lvl|blvl)\)",
        repl=partial(_matched_skill_level, skill_levels=skill_levels),
        string=calc_expression,
    )

def _evaluate_sklvl_calcs(calc_expression, skill, skill_levels, lvl):
    return re.sub(
        pattern=r"sklvl\('((?:\w|\s)+)'\.(\w+)\.(?!lvl)(\w+)\)",
        repl=partial(_matched_sklvl_calc, skill=skill, skill_levels=skill_levels, lvl=lvl),
        string=calc_expression,
    )

def _evaluate_other_entity_calcs(calc_expression, skill, skill_levels, lvl):
    return re.sub(
        pattern=r"(skill|miss)\('((?:\w|\s)+)'\.(?!lvl)(\w+)\)",
        repl=partial(_matched_other_entity_calc, skill=skill, skill_levels=skill_levels, lvl=lvl),
        string=calc_expression,
    )

def  _evaluate_calcs(calc_expression, skill, skill_levels, lvl):
    return re.sub(
        pattern='|'.join(CALC_LOOKUP.keys()),
        repl=partial(_matched_calc, skill=skill, skill_levels=skill_levels, lvl=lvl),
        string=calc_expression,
    )

def _fill_if_thens(calc_expression):
    return re.sub(
        pattern=r'\(?(\(.*\))\s\?\s?(.*)\s?:\s?(\(?[^\.|+]*\)?)',
        repl=lambda match: match[2] if numexpr.evaluate(match[1]).item() else match[3],
        string=calc_expression,
    )

def _evaluate_mins(calc_expression):
    RE_MATH_SYMBOLS = '(?:\d|\+|-|\*|\/|\.|\s|\(|\))'
    return re.sub(
        pattern=fr"min\(({RE_MATH_SYMBOLS}+),\s*({RE_MATH_SYMBOLS}+)\)",
        repl=_matched_min_function,
        string=calc_expression,
    )

def _matched_skill_level(match, skill_levels):
    return str(skill_levels.get(match[1], 0))

def _matched_sklvl_calc(match, skill, skill_levels, lvl):
    other_skill = skill[f'relatedSkills'][match[1]]
    lvl_calculator = CALC_LOOKUP[match[2]]
    calculator = CALC_LOOKUP[match[3]]

    effective_lvl = lvl_calculator(skill, skill_levels, lvl)
    return str(calculator(other_skill, skill_levels, effective_lvl))

def _matched_other_entity_calc(match, skill, skill_levels, lvl):
    entity_kind = {'miss': 'Missile', 'skill': 'Skill'}[match[1]]
    entity_name = match[2]
    entity = skill[f'related{entity_kind}s'][entity_name]
    
    calculator = CALC_LOOKUP[match[3]]
    lvl = skill_levels.get(entity_name, 0) if entity_kind == 'Skill' else lvl
    return str(calculator(entity, skill_levels, lvl))
        
def _matched_calc(match, skill, skill_levels, lvl):
    calculator = CALC_LOOKUP[match[0]]
    return str(calculator(skill, skill_levels, lvl))

def _matched_min_function(match):
    return min(match[1], match[2])

# %%
CALC_LOOKUP = {
    'toht': calculate_to_hit,
    'edmn': calculate_elemental_damage_min,
    'edmx': calculate_elemental_damage_max,
    'edln': calculate_length,
    'edns': lambda skill, skill_levels, lvl: 256 * calculate_elemental_damage_min(skill, skill_levels, lvl),
    'edxs': lambda skill, skill_levels, lvl: 256 * calculate_elemental_damage_max(skill, skill_levels, lvl),
    'ln12': create_linear_calculator('par1', 'par2'),
    'ln34': create_linear_calculator('par3', 'par4'),
    'ln56': create_linear_calculator('par5', 'par6'),
    'ln78': create_linear_calculator('par7', 'par8'),
    'dm12': create_diminishing_calculator('par1', 'par2'),
    'dm34': create_diminishing_calculator('par3', 'par4'),
    'dm56': create_diminishing_calculator('par5', 'par6'),
    'dm78': create_diminishing_calculator('par7', 'par8'),
    'math': create_mastery_calculator('passiveMasteryTh'),
    'madm': create_mastery_calculator('passiveMasteryDmg'),
    'macr': create_mastery_calculator('passiveMasteryCrit'),
    'm1eo': partial(calculate_mXeo, missile_num=1),
    'm1ey': partial(calculate_mXey, missile_num=1),
    'm2eo': partial(calculate_mXeo, missile_num=2),
    'm2ey': partial(calculate_mXey, missile_num=2),
    'm3eo': partial(calculate_mXeo, missile_num=3),
    'm3ey': partial(calculate_mXey, missile_num=3),
    'm1en': partial(calculate_elemental_damage_min, missile_num=1),
    'm1ex': partial(calculate_elemental_damage_max, missile_num=1),
    'm2en': partial(calculate_elemental_damage_min, missile_num=2),
    'm2ex': partial(calculate_elemental_damage_max, missile_num=2),
    'm3en': partial(calculate_elemental_damage_min, missile_num=3),
    'm3ex': partial(calculate_elemental_damage_max, missile_num=3),
    'mps': calculate_mana_cost_per_second,
    'usmc': partial(calculate_mana_cost, multiplier=256),
    'len': create_calculator_on_calc_field('auraLen'),
    'lvl': lambda skill, skill_levels, lvl: lvl,
    **{f'clc{i}': create_calculator_on_calc_field(f'calc{i}') for i in range(1, N_CALC_FIELDS + 1)},
    **{f'par{i}': partial(_get_param, param_number=i) for i in range(1, N_PARAMS + 1)},
}

# %% [markdown]
# ## Define formatters

# %%
FRAMES_PER_SECOND = 25
YARDS_PER_GAME_UNIT = 2 / 3

def format_mana_cost(skill, skill_levels, lvl, ta, tb, ca, cb):
    cost = floor(calculate_mana_cost(skill, skill_levels, lvl), precision=ca or 10)
    return f"{skill['strMana']}{cost}" if cost else ''

def format_attack_rating(skill, skill_levels, lvl, ta, tb, ca, cb):
    attack_rating = calculate_to_hit(skill, skill_levels, lvl)
    if not attack_rating:
        return ''
    return f"Attack: +{attack_rating} percent"

def format_physical_damage(skill, skill_levels, lvl, ta, tb, ca, cb):
    if skill.get('minDam') is None:
        return ''

    min_damage = floor(calculate_physical_damage_min(skill, skill_levels, lvl))
    max_damage = floor(calculate_physical_damage_max(skill, skill_levels, lvl))

    if min_damage == max_damage:
        return f'Damage: +{min_damage}'
    
    return f'Damage: {min_damage}-{max_damage}'

def format_elemental_damage(skill, skill_levels, lvl, ta, tb, ca, cb):
    if skill.get('eMin') is None:
        return ''
    
    min_damage = floor(calculate_elemental_damage_min(skill, skill_levels, lvl))
    max_damage = floor(calculate_elemental_damage_max(skill, skill_levels, lvl))

    if min_damage == max_damage:
        return f"{skill['eType']} Damage: +{min_damage}"
    
    return f"{skill['eType']} Damage: {min_damage}-{max_damage}"

def format_physical_damage_with_text(skill, skill_levels, lvl, ta, tb, ca, cb):
    if skill.get('minDam') is None:
        return ''
    
    min_damage = floor(calculate_physical_damage_min(skill, skill_levels, lvl))
    max_damage = floor(calculate_physical_damage_max(skill, skill_levels, lvl))
    
    return f"{tb or ''}{ta or ''} {min_damage}-{max_damage}"

def format_elemental_damage_with_text(skill, skill_levels, lvl, ta, tb, ca, cb):
    if skill.get('eMin') is None:
        return ''
    
    min_damage = floor(calculate_elemental_damage_min(skill, skill_levels, lvl))
    max_damage = floor(calculate_elemental_damage_max(skill, skill_levels, lvl))
    
    return f"{tb or ''}{ta or ''} {min_damage}-{max_damage}"

def format_elemental_length(skill, skill_levels, lvl, ta, tb, ca, cb):
    if not skill.get('eLen'):
        return ''
    
    length = calculate_length(skill, skill_levels, lvl)
    formatted_length = int_if_no_decimals(length / FRAMES_PER_SECOND)
    return f"{skill['eType']} Length: {formatted_length} seconds"

def format_poison_damage(skill, skill_levels, lvl, ta, tb, ca, cb):
    if skill.get('eMin') is None:
        return ''
    
    adjustment = 1 if skill.get('hitShift') else 2 ** -8  # skills without hitshift 
    
    length = calculate_length(skill, skill_levels, lvl)
    min_damage = floor(length * calculate_elemental_damage_min(skill, skill_levels, lvl))
    max_damage = floor(length * calculate_elemental_damage_max(skill, skill_levels, lvl))
    formatted_length = int_if_no_decimals(length / FRAMES_PER_SECOND)
    return f'Poison Damage: {min_damage}-{max_damage}\nover {formatted_length} seconds'

def format_elemental_damage_over_time(skill, skill_levels, lvl, ta, tb, ca, cb):
    min_damage = floor(FRAMES_PER_SECOND * calculate_elemental_damage_min(skill, skill_levels, lvl))
    max_damage = floor(FRAMES_PER_SECOND * calculate_elemental_damage_max(skill, skill_levels, lvl))
    return f"Average {skill['eType']} Damage: {min_damage}-{max_damage} per second"

def format_elemental_damage_over_time_with_text(skill, skill_levels, lvl, ta, tb, ca, cb):
    calca = floor(calculate_skill_value(ca, skill, skill_levels, lvl))
    calcb = floor(calculate_skill_value(cb, skill, skill_levels, lvl))
    return f"{tb or ''}{ta or ''}{calca}-{calcb} per second"

def format_fire_missile_damage_over_time(skill, skill_levels, lvl, ta, tb, ca, cb):
    adjustment = 2.34 * 2 ** 5  # tuned, just higher than 7/3
    min_damage = floor(adjustment * calculate_elemental_damage_min(skill, skill_levels, lvl, missile_num=1))
    max_damage = floor(adjustment * calculate_elemental_damage_max(skill, skill_levels, lvl, missile_num=1))
    return f'Average Fire Damage: {min_damage}-{max_damage} per second'

def format_fire_damage_over_time(skill, skill_levels, lvl, ta, tb, ca, cb):
    adjustment = 2.34 * 2 ** 5  # tuned, just higher than 7/3
    min_damage = floor(adjustment * calculate_elemental_damage_min(skill, skill_levels, lvl))
    max_damage = floor(adjustment * calculate_elemental_damage_max(skill, skill_levels, lvl))
    return f'Average Fire Damage: {min_damage}-{max_damage} per second'

def format_missile_range_in_yards(skill, skill_levels, lvl, ta, tb, ca, cb):
    missile_range = skill['missile1']['range'] + skill['missile1'].get('levRange', 0) * (lvl - 1)
    formatted_range = floor(missile_range * YARDS_PER_GAME_UNIT, 10)
    return f'{formatted_range} yards'

def format_missile_damage(skill, skill_levels, lvl, ta, tb, ca, cb):
    missile = skill['missile1']
    min_damage = floor(calculate_elemental_damage_min(missile, skill_levels, lvl))
    max_damage = floor(calculate_elemental_damage_max(missile, skill_levels, lvl))
    return f'{ta}{min_damage}-{max_damage}'

def format_missile_duration(skill, skill_levels, lvl, ta, tb, ca, cb):
    duration = skill['missile1']['range'] + skill['missile1'].get('levRange', 0) * (lvl - 1)
    formatted_duration = int_if_no_decimals(duration / FRAMES_PER_SECOND)
    return f'{ta}{formatted_duration} seconds'

def format_cltsubmissile_duration(skill, skill_levels, lvl, ta, tb, ca, cb):
    missile = skill['missile1']['cltSubMissile1']
    duration = missile['range'] + missile.get('levRange', 0) * (lvl - 1)
    formatted_duration = int_if_no_decimals(duration / FRAMES_PER_SECOND)
    return f'{ta}{formatted_duration} seconds'

def format_minion_life(skill, skill_levels, lvl, ta, tb, ca, cb):
    base_life = (skill['summon']['minHPNormal'] + skill['summon']['maxHPNormal']) / 2
    calca = calculate_skill_value(ca, skill, skill_levels, lvl) or 0
    calcb = calculate_skill_value(cb, skill, skill_levels, lvl) or 0
    
    life = floor((1 + calca / 100) * (base_life + calcb))
    return f'Life: {life}'

def format_skeleton_damage(skill, skill_levels, lvl, ta, tb, ca, cb):
    mastery_damage = skill_levels.get('skeletonMastery', 0) * skill['relatedSkills']['skeletonMastery']['params']['par2']
    monster_min_damage = skill['summon']['a1MinDNormal']
    monster_max_damage = skill['summon']['a1MaxDNormal']
    
    skill_damage = calculate_elemental_damage_min(skill, skill_levels, lvl)
    bonus = (lvl - 3) * skill['params']['par3'] if lvl > 3 else 0
    multiplier = 1 + bonus / 100

    min_damage = floor(multiplier * (monster_min_damage + skill_damage + mastery_damage))
    max_damage = floor(multiplier * (monster_max_damage + skill_damage + mastery_damage))

    return f'Damage: {min_damage}-{max_damage}'

def format_golem_damage(skill, skill_levels, lvl, ta, tb, ca, cb):
    damage_bonus = 0 if skill['strName'] == 'Iron Golem' else 35 * (lvl - 1)
    damage_multiplier = 1 + damage_bonus / 100
    
    monster_min_damage = skill['summon']['a1MinDNormal']
    monster_max_damage = skill['summon']['a1MaxDNormal']
    
    min_damage = floor(damage_multiplier * monster_min_damage)
    max_damage = floor(damage_multiplier * monster_max_damage)
    return f'Damage: {min_damage}-{max_damage}'

def format_fire_golem_damage(skill, skill_levels, lvl, ta, tb, ca, cb):
    monster_min_damage = skill['summon']['a1MinDNormal']
    monster_max_damage = skill['summon']['a1MaxDNormal']
    
    holy_fire_min_damage = calculate_skill_value(ca, skill, skill_levels, lvl)
    holy_fire_max_damage = calculate_skill_value(cb, skill, skill_levels, lvl)
    
    min_damage = floor(monster_min_damage + holy_fire_min_damage)
    max_damage = floor(monster_max_damage + holy_fire_max_damage)
    return f'Fire Damage: {min_damage}-{max_damage}'

def format_half_radius(skill, skill_levels, lvl, ta, tb, ca, cb):
    calca = calculate_skill_value(ca, skill, skill_levels, lvl)
    radius = floor(floor(calca) * YARDS_PER_GAME_UNIT / 2, precision=10)
    return f'{ta}{radius} yards'

def _fill_ta_with_tb(skill, skill_levels, lvl, ta, tb, ca, cb, pattern):
    return ta.replace(pattern, tb)

def _fill_ta_with_calca(skill, skill_levels, lvl, ta, tb, ca, cb, pattern):
    return ta.replace(pattern, str(calculate_skill_value(ca, skill, skill_levels, lvl)))

def format_text_on_calc_condition(skill, skill_levels, lvl, ta, tb, ca, cb):
    calca = floor(calculate_skill_value(ca, skill, skill_levels, lvl))
    return f'{calca}{ta if calca == 1 else tb}'

def create_simple_formatter(template):
    def formatter(skill, skill_levels, lvl, ta, tb, ca, cb):
        return template.format(ta=ta or '', tb=tb or '')
    return formatter

def create_calc_formatter(template, frames=False, game_units=False, precision=None, multiplier=None):
    def formatter(skill, skill_levels, lvl, ta, tb, ca, cb):
        calca = calculate_skill_value(ca, skill, skill_levels, lvl)
        calcb = calculate_skill_value(cb, skill, skill_levels, lvl)
        
        calca = _convert_calc(calca, frames, game_units, precision, multiplier)
        calcb = _convert_calc(calcb, frames, game_units, precision, multiplier)

        formatted = template.format(ta=ta or '', tb=tb or '', calca=calca, calcb=calcb)
        return formatted if calca or calcb else ''
    return formatter

def _convert_calc(calc, frames, game_units, precision, multiplier):
    if calc is None:
        return calc
    if frames:
        calc /= FRAMES_PER_SECOND
    if game_units:
        calc = floor(calc) * YARDS_PER_GAME_UNIT
    if multiplier is not None:
        calc *= multiplier
    if precision is not None:
        calc = floor(calc, precision)
    return calc

# %%
FORMATTERS_BY_DESCLINE = {
    1: format_mana_cost,
    2: create_calc_formatter('{ta} {calca:+d}{tb}', precision=1),
    3: create_calc_formatter('{ta}{calca}{tb}', precision=1),
    4: create_calc_formatter('{ta}+{calca}'),
    5: create_calc_formatter('{ta} {calca}', precision=1),
    6: create_calc_formatter('+{calca} {ta}'),
    7: create_calc_formatter('{calca} {ta}'),
    8: format_attack_rating,
    9: format_physical_damage,
    10: format_elemental_damage,
    11: format_elemental_length,
    12: create_calc_formatter('{ta}{calca} seconds', frames=True, precision=10),
    13: format_minion_life,
    14: format_poison_damage,
    15: create_simple_formatter('{ta}:{tb}'),  #not used
    16: create_calc_formatter('Duration: {calca}-{calcb} seconds', frames=True),
    17: format_elemental_damage_over_time_with_text,
    18: create_simple_formatter('{ta}'),
    19: create_calc_formatter('{tb}{ta} {calca} yards', game_units=True, precision=10),
    20: create_calc_formatter('{ta}+{calca} percent {tb}'),  # not used
    21: create_calc_formatter('{ta}{calca} percent {tb}'),  # not used
    22: format_fire_missile_damage_over_time,
    23: format_missile_duration,
    24: format_elemental_damage_with_text,
    25: create_simple_formatter('{ta}{tb}'),
    26: format_elemental_damage_over_time,
    27: format_fire_damage_over_time,
    28: create_simple_formatter('Radius: 1 yard'),
    29: format_missile_range_in_yards,
    30: format_cltsubmissile_duration,
    31: create_calc_formatter('{ta} {calca} seconds', frames=True, precision=10),
    32: create_calc_formatter('{ta}{tb}+{calca} percent'),
    33: create_simple_formatter('{ta}{tb}'),
    34: format_skeleton_damage,
    35: create_calc_formatter('{ta}: {calca}-{calcb}', precision=1),
    36: format_text_on_calc_condition,
    37: format_half_radius,
    38: create_calc_formatter('{ta}{calca}-{calcb}{tb}', precision=1),
    39: format_golem_damage,
    40: partial(_fill_ta_with_tb, pattern='%s'),  # ca refers to color, ignored here
    41: format_fire_golem_damage,
    42: create_calc_formatter('{ta}: +{calca}.{calcb} {tb}', precision=1),
    43: create_calc_formatter('{ta}{calca}-{calcb}{tb}', precision=10, multiplier=1/256),
    44: create_calc_formatter('{ta}{calca}-{calcb}{tb}', precision=10, multiplier=1/256),  # not used
    # 45: not used
    46: create_simple_formatter('{ta}'),  # not used
    47: create_calc_formatter('{ta}{calca}-{calcb}', precision=1),
    48: format_elemental_damage,
    49: format_physical_damage_with_text,
    50: format_missile_damage,
    51: partial(_fill_ta_with_calca, pattern='%d'),
    52: create_calc_formatter('{ta}+{calca}-{calcb}{tb}', precision=1),
    #53: not used
    #54: not used
    #55: not used
    #56: not used
    57: create_calc_formatter('{ta}+{calca} seconds', frames=True, precision=1),
    58: create_calc_formatter('{ta}{tb}+{calca}-{calcb}', precision=1),  # not used
    59: create_calc_formatter('{tb}{ta}{calca}-{calcb}', precision=1),
    60: create_calc_formatter('{ta}+{calcb}{tb}'),  # not used, 256 precision
    61: create_calc_formatter('{ta}{calca}{tb}', precision=10, multiplier=1/256),
    62: create_calc_formatter('{ta}{tb}{calca}-{calcb}', precision=1),
    63: create_calc_formatter('{ta}: +{calca}% {tb}'),
    64: create_calc_formatter('{ta}: +{calca}/{calcb} {tb}', precision=1),  #not used
    65: create_simple_formatter('{ta}: {tb}'),  # not used
    66: partial(_fill_ta_with_calca, pattern='%d%'),
    67: create_calc_formatter('{ta}: +{calca} {tb}', precision=1),
    68: create_calc_formatter('{calca}{ta}{tb}'),
    69: create_calc_formatter('{ta}: {tb} {calca}'),  # not used
    70: create_calc_formatter('{ta}{tb}+{calca}'),
    71: create_simple_formatter('{ta}: {tb}'),
    72: create_calc_formatter('+{calca}/{calcb} {ta}'),
    73: create_calc_formatter('{calca}/{calcb} {ta}'),
    74: create_simple_formatter('{ta}'),  # not used
    75: create_simple_formatter('{ta}'),  #not used
}

def format_descline(descline_number, skill, skill_levels, lvl, ta, tb, ca, cb):
    formatter = FORMATTERS_BY_DESCLINE[descline_number]
    return formatter(skill, skill_levels, lvl, ta, tb, ca, cb)

# %% [markdown]
# ## Format skills

# %%
def format_skill(skill, skill_levels, lvl):
    lines = [
        skill['strName'],
        skill['strLong'],
        '',
        format_desclines('dsc2', skill, skill_levels, lvl),
        f'Current Level: {lvl}',
        format_desclines('desc', skill, skill_levels, lvl),
        f'Next Level: {lvl + 1}',
        format_desclines('desc', skill, skill_levels, lvl + 1),
        format_desclines('dsc3', skill, skill_levels, lvl),
    ]
    return '\n'.join([line for line in lines if line is not None])

def format_desclines(root, skill, skill_levels, lvl):
    lines = []
    for entry in skill.get(f'{root}Lines', []):
        line = format_descline(
            descline_number=entry[f'{root}Line'],
            skill=skill,
            skill_levels=skill_levels,
            lvl=lvl,
            ta=entry.get(f'{root}TextA'),
            tb=entry.get(f'{root}TextB'),
            ca=entry.get(f'{root}CalcA'),
            cb=entry.get(f'{root}CalcB'),
        )
        if line:
            lines.append(line)
    return '\n'.join(lines) + '\n' if lines else None

# %%
# print(format_skill(skill_details['summonSpiritWolf'], {}, 10))

# %%
# skill_details['summonSpiritWolf']

# %% [markdown]
# # Format all skills

# %%
for skill_name, skill in skill_details.items():
    print(format_skill(skill, {'clayGolem': 1}, 10))
    print('------------------------------------')
    print('------------------------------------')
    print()
# Out:
# Magic Arrow
# creates a magical arrow or bolt
# that does extra damage
#
# Current Level: 10
# Converts 10% Physical Damage to Magic Damage
# Attack: +91 percent
# Damage: +10
# Mana Cost: 0.3
#
# Next Level: 11
# Converts 11% Physical Damage to Magic Damage
# Attack: +100 percent
# Damage: +11
# Mana Cost: 0.2
#
# ------------------------------------
# ------------------------------------
#
# Fire Arrow
# magically enhances your arrows
# or bolts with fire
#
# Current Level: 10
# Converts 21% Physical Damage to Elemental Damage
# Attack: +91 percent
# Fire Damage: 21-24
# Mana Cost: 4.1
#
# Next Level: 11
# Converts 23% Physical Damage to Elemental Damage
# Attack: +100 percent
# Fire Damage: 24-27
# Mana Cost: 4.2
#
# Fire Arrow Receives Bonuses From:
# Exploding Arrow: +12% Fire Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Inner Sight
# illuminates nearby enemies
# making them easier to hit
# for you and your party
#
# Current Level: 10
# Duration: 44 seconds
# Enemy Defense:  -305
# Radius:  13.3 yards
# Mana Cost: 5
#
# Next Level: 11
# Duration: 48 seconds
# Enemy Defense:  -350
# Radius:  13.3 yards
# Mana Cost: 5
#
# ------------------------------------
# ------------------------------------
#
# Critical Strike
# passive - your attacks have a chance to do double damage
#
# Current Level: 10
# 56  percent chance
#
# Next Level: 11
# 58  percent chance
#
# ------------------------------------
# ------------------------------------
#
# Jab
# attacks with a series of rapid thrusts
# using a javelin or spear class weapon
#
# Multiple Hits
#
# Current Level: 10
# Attack:  +91 percent
# Damage:  +12 percent
# Mana Cost: 4.2
#
# Next Level: 11
# Attack:  +100 percent
# Damage:  +15 percent
# Mana Cost: 4.5
#
# ------------------------------------
# ------------------------------------
#
# Cold Arrow
# magically enhances your arrows or bolts
# by adding cold damage and a slowing effect
# cold arrows only do half of their regular damage
#
# Current Level: 10
# Converts 21% Physical Damage to Elemental Damage
# Attack: +91 percent
# Cold Damage: 22-23
# Cold Length: 14.8 seconds
# Mana Cost: 4.6
#
# Next Level: 11
# Converts 23% Physical Damage to Elemental Damage
# Attack: +100 percent
# Cold Damage: 24-25
# Cold Length: 16 seconds
# Mana Cost: 4.7
#
# Cold Arrow Receives Bonuses From:
# Ice Arrow: +12% Cold Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Multiple Shot
# magically splits one arrow
# or bolt into many
#
# 3/4 Weapon Damage
#
# Current Level: 10
# 11  arrows
# Mana Cost: 13
#
# Next Level: 11
# 12  arrows
# Mana Cost: 14
#
# ------------------------------------
# ------------------------------------
#
# Dodge
# passive - you have a chance to dodge
# a melee attack when attacking
# or standing still
#
# Current Level: 10
# 47  percent chance
#
# Next Level: 11
# 49  percent chance
#
# ------------------------------------
# ------------------------------------
#
# Power Strike
# adds lightning damage to attacks with
# javelin and spear class weapons
#
# Current Level: 10
# Attack: +128 percent
# Lightning Damage: 1-214
# Mana Cost: 4.2
#
# Next Level: 11
# Attack: +140 percent
# Lightning Damage: 1-250
# Mana Cost: 4.5
#
# Power Strike Receives Bonuses From:
# Lightning Bolt: +10% Lightning Damage per Level
# Charged Strike: +10% Lightning Damage per Level
# Lightning Strike: +10% Lightning Damage per Level
# Lightning Fury: +10% Lightning Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Poison Javelin
# magically enhances your javelin
# to leave a trail of poison clouds
#
# Current Level: 10
# Poison Damage: 528-589
# over 26 seconds
# Mana Cost: 6.2
#
# Next Level: 11
# Poison Damage: 656-732
# over 28 seconds
# Mana Cost: 6.5
#
# Poison Javelin Receives Bonuses From:
# Plague Javelin: +12% Poison Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Exploding Arrow
# enchants an arrow or bolt that explodes on
# contact, damaging all nearby enemies
#
# Current Level: 10
# Attack: +101 percent
# Fire Damage: 51-57
# Mana Cost: 9.5
#
# Next Level: 11
# Attack: +110 percent
# Fire Damage: 58-65
# Mana Cost: 10
#
# Exploding Arrow Receives Bonuses From:
# Fire Arrow: +12% Fire Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Slow Missiles
# illuminates nearby enemies and slows their ranged attacks
#
# Current Level: 10
# Duration: 66 seconds
# Ranged attacks slowed to 33 percent
# Radius:  13.3 yards
# Mana Cost: 5
#
# Next Level: 11
# Duration: 72 seconds
# Ranged attacks slowed to 33 percent
# Radius:  13.3 yards
# Mana Cost: 5
#
# ------------------------------------
# ------------------------------------
#
# Avoid
# passive - you have a chance to dodge enemy missiles
# when attacking or standing still
#
# Current Level: 10
# 56  percent chance
#
# Next Level: 11
# 57  percent chance
#
# ------------------------------------
# ------------------------------------
#
# Impale
# increases attack damage but rapidly degrades the weapon
#
# Current Level: 10
# Damage:  +525 percent
# Attack:  +325 percent
# Chance of losing durability: 30 percent
# Mana Cost: 3
#
# Next Level: 11
# Damage:  +550 percent
# Attack:  +350 percent
# Chance of losing durability: 29 percent
# Mana Cost: 3
#
# ------------------------------------
# ------------------------------------
#
# Lightning Bolt
# magically converts your javelin into a bolt of lightning
#
# 3/4 Weapon Damage
# Converts 100% Physical Damage to Elemental Damage
#
# Current Level: 10
# Lightning Damage: 1-160
# Mana Cost: 8.2
#
# Next Level: 11
# Lightning Damage: 1-178
# Mana Cost: 8.5
#
# Lightning Bolt Receives Bonuses From:
# Power Strike: +3% Lightning Damage per Level
# Charged Strike: +3% Lightning Damage per Level
# Lightning Strike: +3% Lightning Damage per Level
# Lightning Fury: +3% Lightning Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Ice Arrow
# magically enhances your arrow or bolt
# to freeze your enemies
#
# Current Level: 10
# Attack: +101 percent
# Cold Damage: 72-78
# Freezes for 3.8 seconds
# Mana Cost: 6.2
#
# Next Level: 11
# Attack: +110 percent
# Cold Damage: 84-91
# Freezes for 4 seconds
# Mana Cost: 6.5
#
# Ice Arrow Receives Bonuses From:
# Cold Arrow: +8% Cold Damage per Level
# Freezing Arrow: +5% Freeze Length per Level
#
# ------------------------------------
# ------------------------------------
#
# Guided Arrow
# enhances your arrows and bolts
# to track your target
# or seek one of its own
# always hits
#
# Current Level: 10
# Damage:  +45 percent
# Mana Cost: 5.7
#
# Next Level: 11
# Damage:  +50 percent
# Mana Cost: 5.5
#
# ------------------------------------
# ------------------------------------
#
# Penetrate
# passive - increases your attack rating
#
# Current Level: 10
# To Attack Rating:  +125 percent
#
# Next Level: 11
# To Attack Rating:  +135 percent
#
# ------------------------------------
# ------------------------------------
#
# Charged Strike
# adds lightning damage to javelin and spear class weapons
# and releases charged bolts upon impact
#
# Current Level: 10
# Releases 5 charged bolts
# Lightning Damage: 1-146
# Mana Cost: 6.2
#
# Next Level: 11
# Releases 5 charged bolts
# Lightning Damage: 1-162
# Mana Cost: 6.5
#
# Charged Strike Receives Bonuses From:
# Power Strike: +10% Lightning Damage per Level
# Lightning Bolt: +10% Lightning Damage per Level
# Lightning Strike: +10% Lightning Damage per Level
# Lightning Fury: +10% Lightning Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Plague Javelin
# magically enhances your javelin to release
# expanding clouds of poison upon impact
#
# Current Level: 10
# Attack:  +111 percent
# Poison Damage: 391-422
# over 6.6 seconds
# Mana Cost: 11.5
#
# Next Level: 11
# Attack:  +120 percent
# Poison Damage: 481-514
# over 7 seconds
# Mana Cost: 12
#
# Plague Javelin Receives Bonuses From:
# Poison Javelin: +10% Poison Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Strafe
# magically splits one arrow into several
# that target multiple nearby enemies
#
# 3/4 Weapon Damage
#
# Current Level: 10
# Attacks up to 10 targets
# Damage:  +50 percent
# Mana Cost: 11
#
# Next Level: 11
# Attacks up to 10 targets
# Damage:  +55 percent
# Mana Cost: 11
#
# ------------------------------------
# ------------------------------------
#
# Immolation Arrow
# enhances arrows or bolts to
# cause severe fire damage and
# creates a pyre upon impact
#
# Current Level: 10
# Attack:  +111 percent
# Fire Explosion Damage:  142-153
# Fire Duration: 4 seconds
# Average Fire Damage: 60-63 per second
# Mana Cost: 10.5
#
# Next Level: 11
# Attack:  +120 percent
# Fire Explosion Damage:  165-176
# Fire Duration: 4 seconds
# Average Fire Damage: 66-69 per second
# Mana Cost: 11
#
# Immolation Arrow Receives Bonuses From:
# Fire Arrow: +5% Average Fire Damage per Second per Level
# Exploding Arrow: +10% Fire Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Decoy
# creates a duplicate of yourself
# that draws fire from enemies
#
# Current Level: 10
# Life:  +100 percent
# Duration: 55 seconds
# Mana Cost: 12.2
#
# Next Level: 11
# Life:  +110 percent
# Duration: 60 seconds
# Mana Cost: 11.5
#
# ------------------------------------
# ------------------------------------
#
# Evade
# passive - you have a chance to dodge
# a melee or missile attack
# when walking or running
#
# Current Level: 10
# 47  percent chance
#
# Next Level: 11
# 49  percent chance
#
# ------------------------------------
# ------------------------------------
#
# Fend
# attacks all adjacent targets
#
# Current Level: 10
# Attack Bonus:  +130 percent
# Damage:  +160 percent
# Mana Cost: 5
#
# Next Level: 11
# Attack Bonus:  +140 percent
# Damage:  +170 percent
# Mana Cost: 5
#
# ------------------------------------
# ------------------------------------
#
# Freezing Arrow
# magically enhances an arrow or bolt
# to freeze entire groups of monsters
#
# Radius:  3.3 yards
#
# Current Level: 10
# Attack:  +121 percent
# Cold Damage: 140-150
# Freezes for 2 seconds
# Mana Cost: 13.5
#
# Next Level: 11
# Attack:  +130 percent
# Cold Damage: 155-165
# Freezes for 2 seconds
# Mana Cost: 14
#
# Freezing Arrow Receives Bonuses From:
# Cold Arrow: +12% Cold Damage per Level
# Ice Arrow: +5% Freeze Length per Level
#
# ------------------------------------
# ------------------------------------
#
# Valkyrie
# summons a powerful Valkyrie ally
#
# Current Level: 10
# Life: 1232
# Damage:  +225 percent
# Attack: +400
# Defense Bonus:  +90 percent
# Mana Cost: 34
#
# Next Level: 11
# Life: 1320
# Damage:  +250 percent
# Attack: +440
# Defense Bonus:  +100 percent
# Mana Cost: 35
#
# Valkyrie Receives Bonuses From:
# Decoy: +20% Life per Level
# Penetrate: +40 Attack Rating per Level
# Critical Strike
# Dodge
# Avoid
# Evade
#
# ------------------------------------
# ------------------------------------
#
# Pierce
# passive - your missiles have a chance to
# pass through enemies that they hit
#
# Current Level: 10
# 71  percent chance
#
# Next Level: 11
# 74  percent chance
#
# ------------------------------------
# ------------------------------------
#
# Lightning Strike
# adds lightning damage to javelin and spear class weapons
# and releases chain lightning upon impact
#
# Current Level: 10
# 11  hits
# Lightning Damage: 1-125
# Mana Cost: 9
#
# Next Level: 11
# 12  hits
# Lightning Damage: 1-140
# Mana Cost: 9
#
# Lightning Strike Receives Bonuses From:
# Power Strike: +8% Lightning Damage per Level
# Lightning Bolt: +8% Lightning Damage per Level
# Charged Strike: +8% Lightning Damage per Level
# Lightning Fury: +8% Lightning Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Lightning Fury
# changes a thrown javelin into a powerful
# bolt of lightning that splits on impact
#
# Current Level: 10
# Releases 11 bolts
# Lightning Damage: 1-240
# Mana Cost: 14.5
#
# Next Level: 11
# Releases 12 bolts
# Lightning Damage: 1-270
# Mana Cost: 15
#
# Lightning Fury Receives Bonuses From:
# Power Strike: +1% Lightning Damage per Level
# Lightning Bolt: +1% Lightning Damage per Level
# Charged Strike: +1% Lightning Damage per Level
# Lightning Strike: +1% Lightning Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Fire Bolt
# creates a magical flaming missile
#
# Mana Cost: 2.5
#
# Current Level: 10
# Fire Damage: 17-22
#
# Next Level: 11
# Fire Damage: 19-25
#
# Fire Bolt Receives Bonuses From:
# Fire Ball: +16% Fire Damage per Level
# Meteor: +16% Fire Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Warmth
# passive - increases the rate at which you recover mana
#
# Current Level: 10
# 138  percent
#
# Next Level: 11
# 150  percent
#
# ------------------------------------
# ------------------------------------
#
# Charged Bolt
# creates multiple, randomly directed
# bolts of electrical energy
#
# Current Level: 10
# Lightning Damage: 6-8
# 12  bolts
# Mana Cost: 7.5
#
# Next Level: 11
# Lightning Damage: 7-9
# 13  bolts
# Mana Cost: 8
#
# Charged Bolt Receives Bonuses From:
# Lightning: +6% Lightning Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Ice Bolt
# creates a magical bolt of ice
# that damages and slows your enemies
#
# Current Level: 10
# Cold Damage: 14-20
# Cold Length: 18.6 seconds
# Mana Cost: 3
#
# Next Level: 11
# Cold Damage: 16-23
# Cold Length: 20 seconds
# Mana Cost: 3
#
# Ice Bolt Receives Bonuses From:
# Frost Nova: +15% Cold Damage per Level
# Ice Blast: +15% Cold Damage per Level
# Glacial Spike: +15% Cold Damage per Level
# Blizzard: +15% Cold Damage per Level
# Frozen Orb: +15% Cold Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Frozen Armor
# increases your defense rating
# and freezes enemies that hit you
#
# Current Level: 10
# Defense Bonus: 75 percent
# Duration: 228 seconds
# Freezes for 2.2 seconds
# Mana Cost: 7
#
# Next Level: 11
# Defense Bonus: 80 percent
# Duration: 240 seconds
# Freezes for 2.4 seconds
# Mana Cost: 7
#
# Frozen Armor Receives Bonuses From:
# Shiver Armor: +10 Seconds per Level
# Shiver Armor: +5% Freeze Length per Level
# Chilling Armor: +10 Seconds per Level
# Chilling Armor: +5% Freeze Length per Level
#
# ------------------------------------
# ------------------------------------
#
# Inferno
# creates a continuous jet of flame
# to scorch your enemies
#
# Minimum Mana Required to Cast:  6
#
# Current Level: 10
# Average Fire Damage: 98-111 per second
# Range:  7.3 yards
# Mana Cost: 8 per second
#
# Next Level: 11
# Average Fire Damage: 108-122 per second
# Range:  8 yards
# Mana Cost: 8 per second
#
# Inferno Receives Bonuses From:
# Warmth: +13% Fire Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Static Field
# creates an electrical field that reduces life
# of all nearby enemies
#
# Weakens Enemies by 25 percent
#
# Current Level: 10
# Radius:  9.3 yards
# Mana Cost: 9
#
# Next Level: 11
# Radius:  10 yards
# Mana Cost: 9
#
# ------------------------------------
# ------------------------------------
#
# Telekinesis
# uses the power of your mind to
# pick up items, use objects,
# and knock back enemies
#
# Current Level: 10
# Lightning Damage: 10-11
# Mana Cost: 7
#
# Next Level: 11
# Lightning Damage: 11-12
# Mana Cost: 7
#
# ------------------------------------
# ------------------------------------
#
# Frost Nova
# creates an expanding ring of ice that damages
# and slows all nearby enemies
#
# Current Level: 10
# Cold Damage: 22-28
# Cold Length: 17 seconds
# Mana Cost: 18
#
# Next Level: 11
# Cold Damage: 25-32
# Cold Length: 18 seconds
# Mana Cost: 19
#
# Frost Nova Receives Bonuses From:
# Blizzard: +10% Cold Damage per Level
# Frozen Orb: +10% Cold Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Ice Blast
# creates a magical sphere of ice that
# damages and freezes your enemy
#
# Current Level: 10
# Cold Damage: 85-93
# Freezes for 4.8 seconds
# Mana Cost: 10.5
#
# Next Level: 11
# Cold Damage: 99-108
# Freezes for 5 seconds
# Mana Cost: 11
#
# Ice Blast Receives Bonuses From:
# Ice Bolt: +8% Cold Damage per Level
# Glacial Spike: +10% Freeze Length per Level
# Blizzard: +8% Cold Damage per Level
# Frozen Orb: +8% Cold Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Blaze
# creates a wall of fire
# in your wake to scorch your enemies
#
# Current Level: 10
# Fire Duration: 12.6 seconds
# Average Fire Damage: 112-131 per second
# Mana Cost: 15.5
#
# Next Level: 11
# Fire Duration: 13.6 seconds
# Average Fire Damage: 126-145 per second
# Mana Cost: 16
#
# Blaze Receives Bonuses From:
# Warmth: +4% Fire Damage per Level
# Fire Wall: +1% Fire Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Fire Ball
# creates an explosive sphere of fiery death
# to engulf your enemies
#
# Radius: 1 yard
#
# Current Level: 10
# Fire Damage: 74-91
# Mana Cost: 9.5
#
# Next Level: 11
# Fire Damage: 86-104
# Mana Cost: 10
#
# Fire Ball Receives Bonuses From:
# Fire Bolt: +14% Fire Damage per Level
# Meteor: +14% Fire Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Nova
# creates an expanding ring of lightning
# to shock nearby enemies
#
# Current Level: 10
# Lightning Damage: 57-94
# Mana Cost: 24
#
# Next Level: 11
# Lightning Damage: 64-103
# Mana Cost: 25
#
# ------------------------------------
# ------------------------------------
#
# Lightning
# creates a powerful lightning bolt
# to lay waste to your enemies
#
# Current Level: 10
# Lightning Damage: 1-120
# Mana Cost: 12.5
#
# Next Level: 11
# Lightning Damage: 1-132
# Mana Cost: 13
#
# Lightning Receives Bonuses From:
# Charged Bolt: +8% Lightning Damage per Level
# Nova: +8% Lightning Damage per Level
# Chain Lightning: +8% Lightning Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Shiver Armor
# increases your defense rating
# freezes and damages enemies that hit you
#
# Current Level: 10
# Duration: 228 seconds
# Defense Bonus: 99 percent
# Cold Damage: 26-32
# Cold Length: 6 seconds
# Mana Cost: 11
#
# Next Level: 11
# Duration: 240 seconds
# Defense Bonus: 105 percent
# Cold Damage: 29-36
# Cold Length: 7 seconds
# Mana Cost: 11
#
# Shiver Armor Receives Bonuses From:
# Frozen Armor: +10 Seconds per Level
# Frozen Armor: +9% Cold Damage per Level
# Chilling Armor: +10 Seconds per Level
# Chilling Armor: +9% Cold Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Fire Wall
# creates a wall of flame that
# blocks or burns your enemies
#
# Current Level: 10
# Fire Duration: 3.6 seconds
# Average Fire Damage: 496-519 per second
# 16.6 yards
# Mana Cost: 31
#
# Next Level: 11
# Fire Duration: 3.6 seconds
# Average Fire Damage: 561-585 per second
# 18 yards
# Mana Cost: 32
#
# Fire Wall Receives Bonuses From:
# Warmth: +4% Fire Damage per Level
# Inferno: +1% Fire Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Enchant
# enchants equipped weapon of targeted character or minion
# adds fire damage to melee weapons
# adds one-third fire damage to ranged weapons
#
# Current Level: 10
# Duration: 360 seconds
# Fire Damage: 25-36
# Attack Bonus:  +101 percent
# Mana Cost: 34
#
# Next Level: 11
# Duration: 384 seconds
# Fire Damage: 29-41
# Attack Bonus:  +110 percent
# Mana Cost: 35
#
# Enchant Receives Bonuses From:
# Warmth: +9% Fire Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Chain Lightning
# creates a bolt of lightning that
# arcs through several targets
#
# Current Level: 10
# 7.0  hits
# Lightning Damage: 1-143
# Mana Cost: 18
#
# Next Level: 11
# 7.2  hits
# Lightning Damage: 1-156
# Mana Cost: 19
#
# Chain Lightning Receives Bonuses From:
# Charged Bolt: +4% Lightning Damage per Level
# Nova: +4% Lightning Damage per Level
# Lightning: +4% Lightning Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Teleport
# instantly moves to a destination within your line of sight
#
# Current Level: 10
# Mana Cost: 15
#
# Next Level: 11
# Mana Cost: 14
#
# ------------------------------------
# ------------------------------------
#
# Glacial Spike
# creates a magical ice comet
# that freezes or kills nearby enemies
#
# Radius:  2.6 yards
#
# Current Level: 10
# Cold Damage: 91-103
# Freezes for 3 seconds
# Mana Cost: 14.5
#
# Next Level: 11
# Cold Damage: 104-117
# Freezes for 3.2 seconds
# Mana Cost: 15
#
# Glacial Spike Receives Bonuses From:
# Ice Bolt: +5% Cold Damage per Level
# Ice Blast: +5% Cold Damage per Level
# Blizzard: +3% Freeze Length per Level
# Frozen Orb: +5% Cold Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Meteor
# summons a meteor from the heavens
# to crush and incinerate your enemies
#
# Current Level: 10
# Fire Damage: 319-357
# Radius:  4 yards
# Average Fire Damage: 124-147 per second
# Mana Cost: 21.5
#
# Next Level: 11
# Fire Damage: 358-398
# Radius:  4 yards
# Average Fire Damage: 135-159 per second
# Mana Cost: 22
#
# Meteor Receives Bonuses From:
# Fire Bolt: +5% Fire Damage per Level
# Fire Ball: +5% Fire Damage per Level
# Inferno: +3% Average Fire Damage per Second per Level
#
# ------------------------------------
# ------------------------------------
#
# Thunder Storm
# summons a deadly thunderstorm that strikes
# your enemies with bolts of lightning
#
# Current Level: 10
# Duration: 104 seconds
# Lightning Damage: 91-190
# Mana Cost: 19
#
# Next Level: 11
# Duration: 112 seconds
# Lightning Damage: 101-200
# Mana Cost: 19
#
# ------------------------------------
# ------------------------------------
#
# Energy Shield
# creates a magical shield that consumes mana
# instead of health when you take damage
#
# Current Level: 10
# Duration: 684 seconds
# Absorbs 59 percent
# Mana Cost: 5
#
# Next Level: 11
# Duration: 744 seconds
# Absorbs 61 percent
# Mana Cost: 5
#
# Energy Shield Receives Bonuses From:
# Telekinesis
#
# ------------------------------------
# ------------------------------------
#
# Blizzard
# summons massive shards of ice to destroy your enemies
#
# Current Level: 10
# Cold Damage: 210-249
# Duration: 4 seconds
# Mana Cost: 32
#
# Next Level: 11
# Cold Damage: 240-280
# Duration: 4 seconds
# Mana Cost: 33
#
# Blizzard Receives Bonuses From:
# Ice Bolt: +5% Cold Damage per Level
# Ice Blast: +5% Cold Damage per Level
# Glacial Spike: +5% Cold Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Chilling Armor
# increases defense and discharges an ice bolt in retaliation
# against ranged attackers
#
# Current Level: 10
# Defense Bonus: 90 percent
# Duration: 198 seconds
# Cold Damage: 15-21
# Mana Cost: 17
#
# Next Level: 11
# Defense Bonus: 95 percent
# Duration: 204 seconds
# Cold Damage: 17-24
# Mana Cost: 17
#
# Chilling Armor Receives Bonuses From:
# Frozen Armor: +10 Seconds per Level
# Frozen Armor: +7% Cold Damage per Level
# Shiver Armor: +10 Seconds per Level
# Shiver Armor: +7% Cold Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Fire Mastery
# passive - increases all damage caused by your fire spells
#
# Current Level: 10
# Fire Damage:  +93 percent
#
# Next Level: 11
# Fire Damage:  +100 percent
#
# ------------------------------------
# ------------------------------------
#
# Hydra
# summons a multi-headed beast of flame
# to reduce your enemies to ashes
#
# Current Level: 10
# Duration: 10 seconds
# Hydra Fire Damage:  67-82
# Mana Cost: 24.5
#
# Next Level: 11
# Duration: 10 seconds
# Hydra Fire Damage:  75-90
# Mana Cost: 25
#
# Hydra Receives Bonuses From:
# Fire Bolt: +3% Fire Damage per Level
# Fire Ball: +3% Fire Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Lightning Mastery
# passive - increases all damage caused by your lightning spells
#
# Current Level: 10
# Lightning Damage:  +158 percent
#
# Next Level: 11
# Lightning Damage:  +170 percent
#
# ------------------------------------
# ------------------------------------
#
# Frozen Orb
# creates a magical globe that sprays a torrent of ice bolts
# to lay waste to your enemies
#
# Current Level: 10
# Cold Damage: 134-143
# Cold Length: 17 seconds
# Mana Cost: 29.5
#
# Next Level: 11
# Cold Damage: 146-156
# Cold Length: 18 seconds
# Mana Cost: 30
#
# Frozen Orb Receives Bonuses From:
# Ice Bolt: +2% Cold Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Cold Mastery
# passive - increases the damage of your cold attacks
# by piercing enemies' resistances to cold
#
# Current Level: 10
# 65  percent
#
# Next Level: 11
# 70  percent
#
# ------------------------------------
# ------------------------------------
#
# Amplify Damage
# curses a group of enemies, increasing
# the non-magic damage they receive
#
# Damage Taken:  +100 percent
#
# Current Level: 10
# Radius:  8 yards
# Duration: 35 seconds
# Mana Cost: 4
#
# Next Level: 11
# Radius:  8.6 yards
# Duration: 38 seconds
# Mana Cost: 4
#
# ------------------------------------
# ------------------------------------
#
# Teeth
# fires a barrage of summoned barbed teeth
#
# Current Level: 10
# 11  teeth
# Magic Damage: 11-14
# Mana Cost: 7.5
#
# Next Level: 11
# 12  teeth
# Magic Damage: 12-15
# Mana Cost: 8
#
# Teeth Receives Bonuses From:
# Bone Wall: +15% Magic Damage per Level
# Bone Spear: +15% Magic Damage per Level
# Bone Prison: +15% Magic Damage per Level
# Bone Spirit: +15% Magic Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Bone Armor
# creates an orbiting shield of bone
# that absorbs melee damage
#
# Current Level: 10
# Absorbs 110 damage
# Mana Cost: 20
#
# Next Level: 11
# Absorbs 120 damage
# Mana Cost: 21
#
# Bone Armor Receives Bonuses From:
# Bone Wall: +15 Damage Absorbed per Level
# Bone Prison: +15 Damage Absorbed per Level
#
# ------------------------------------
# ------------------------------------
#
# Skeleton Mastery
# passive - increases life and damage
# of raised skeletons and revived creatures
#
# Current Level: 10
# Skeletons: Life: +80
# Skeletons: Damage: +20
# Magi: Life: +80
# Magi: Improved Missile Damage
# Monsters: Life: +50 percent
# Monsters: Damage: +100 percent
#
# Next Level: 11
# Skeletons: Life: +88
# Skeletons: Damage: +22
# Magi: Life: +88
# Magi: Improved Missile Damage
# Monsters: Life: +55 percent
# Monsters: Damage: +110 percent
#
# ------------------------------------
# ------------------------------------
#
# Raise Skeleton
# cast on the corpse of a slain monster,
# this raises a skeleton warrior that
# fights for you
#
# Damage: 4-5
#
# Current Level: 10
# Damage:  +49 percent
# Attack:  155
# Defense:  155
# Life: 94
# 5 skeletons total
# Mana Cost: 15
#
# Next Level: 11
# Damage:  +56 percent
# Attack:  170
# Defense:  170
# Life: 105
# 5 skeletons total
# Mana Cost: 16
#
# Raise Skeleton Receives Bonuses From:
# Skeleton Mastery
# Summon Resist
#
# ------------------------------------
# ------------------------------------
#
# Dim Vision
# curses a group of monsters,
# reducing their vision radius
#
# Current Level: 10
# Radius:  8.6 yards
# Duration:  25 seconds
# Mana Cost: 9
#
# Next Level: 11
# Radius:  9.3 yards
# Duration:  27 seconds
# Mana Cost: 9
#
# ------------------------------------
# ------------------------------------
#
# Weaken
# curses a group of enemies,
# reducing the amount of damage they inflict
#
# Target's Damage: -33 percent
#
# Current Level: 10
# Radius:  12 yards
# Duration: 35.6 seconds
# Mana Cost: 4
#
# Next Level: 11
# Radius:  12.6 yards
# Duration: 38 seconds
# Mana Cost: 4
#
# ------------------------------------
# ------------------------------------
#
# Poison Dagger
# adds poison to your dagger attacks
#
# Current Level: 10
# Poison Damage: 129-153
# over 5.6 seconds
# Attack:  +210 percent
# Mana Cost: 5.2
#
# Next Level: 11
# Poison Damage: 155-181
# over 6 seconds
# Attack:  +230 percent
# Mana Cost: 5.5
#
# Poison Dagger Receives Bonuses From:
# Poison Explosion: +20% Poison Damage per Level
# Poison Nova: +20% Poison Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Corpse Explosion
# cast on the corpse of a slain monster,
# it explodes, damaging nearby enemies
#
# Damage: 70-120 percent of corpse Life
#
# Current Level: 10
# Radius: 5.6 yards
# Mana Cost: 24
#
# Next Level: 11
# Radius: 6 yards
# Mana Cost: 25
#
# ------------------------------------
# ------------------------------------
#
# Clay Golem
# creates a golem from the earth
# to fight by your side
#
# Attack:  240
# Defense:  100
#
# Current Level: 10
# Life: 415
# Damage: 8-20
# Attack Bonus: +200
# Slows Enemies: 51 percent
# Mana Cost: 42
#
# Next Level: 11
# Life: 450
# Damage: 9-22
# Attack Bonus: +220
# Slows Enemies: 53 percent
# Mana Cost: 45
#
# Clay Golem Receives Bonuses From:
# Golem Mastery
# Summon Resist
# Blood Golem: +5% Life per Level
# Iron Golem: +35 Defense per Level
# Fire Golem: +6% Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Iron Maiden
# curses a group of enemies, causing them
# to damage themselves when damaging others
#
# Current Level: 10
# 425  percent damage returned
# Duration: 33.6 seconds
# Radius:  4.6 yards
# Mana Cost: 5
#
# Next Level: 11
# 450  percent damage returned
# Duration: 36 seconds
# Radius:  4.6 yards
# Mana Cost: 5
#
# ------------------------------------
# ------------------------------------
#
# Terror
# curses a group of monsters,
# causing them to flee in terror
#
# Radius:  2.6 yards
#
# Current Level: 10
# Duration: 17 seconds
# Mana Cost: 7
#
# Next Level: 11
# Duration: 18 seconds
# Mana Cost: 7
#
# ------------------------------------
# ------------------------------------
#
# Bone Wall
# creates an impassable barrier
# of bone and debris
#
# Current Level: 10
# Life: 61
# Duration: 24 seconds
# Mana Cost: 17
#
# Next Level: 11
# Life: 66
# Duration: 24 seconds
# Mana Cost: 17
#
# Bone Wall Receives Bonuses From:
# Bone Armor: +10% Life per Level
# Bone Prison: +10% Life per Level
#
# ------------------------------------
# ------------------------------------
#
# Golem Mastery
# Enhances Speed and Life of all your Golems
#
# Current Level: 10
# Life:  +200 percent
# Attack Bonus: +250
# Walk/Run Speed:  +27 percent
#
# Next Level: 11
# Life:  +220 percent
# Attack Bonus: +275
# Walk/Run Speed:  +28 percent
#
# ------------------------------------
# ------------------------------------
#
# Raise Skeletal Mage
# cast on the corpse of a slain monster,
# this raises a skeleton mage that
# fights for you
#
# Current Level: 10
# Life: 61
# Defense:  100
# 5 skeleton magi
# Mana Cost: 17
#
# Next Level: 11
# Life: 61
# Defense:  110
# 5 skeleton magi
# Mana Cost: 18
#
# Raise Skeletal Mage Receives Bonuses From:
# Skeleton Mastery
# Summon Resist
#
# ------------------------------------
# ------------------------------------
#
# Confuse
# curses a monster to force it to attack random targets
#
# Current Level: 10
# Radius:  10 yards
# Duration:  28 seconds
# Mana Cost: 13
#
# Next Level: 11
# Radius:  10.6 yards
# Duration:  30 seconds
# Mana Cost: 13
#
# ------------------------------------
# ------------------------------------
#
# Life Tap
# curses a group of monsters so that
# damaging them gives the attacker life
#
# Heals: 50 percent of attack damage
#
# Current Level: 10
# Radius:  8.6 yards
# Duration: 37.6 seconds
# Mana Cost: 9
#
# Next Level: 11
# Radius:  9.3 yards
# Duration: 40 seconds
# Mana Cost: 9
#
# ------------------------------------
# ------------------------------------
#
# Poison Explosion
# cast on the corpse of a slain monster,
# toxic gas is released
# that poisons nearby monsters
#
# Current Level: 10
# Poison Damage: 262-402
# over 5.6 seconds
# Mana Cost: 8
#
# Next Level: 11
# Poison Damage: 318-468
# over 6 seconds
# Mana Cost: 8
#
# Poison Explosion Receives Bonuses From:
# Poison Dagger: +15% Poison Damage per Level
# Poison Nova: +15% Poison Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Bone Spear
# summons a deadly spike of bone to impale your enemies
#
# Current Level: 10
# Magic Damage: 90-98
# Mana Cost: 9.2
#
# Next Level: 11
# Magic Damage: 99-107
# Mana Cost: 9.5
#
# Bone Spear Receives Bonuses From:
# Teeth: +7% Magic Damage per Level
# Bone Wall: +7% Magic Damage per Level
# Bone Prison: +7% Magic Damage per Level
# Bone Spirit: +7% Magic Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Blood Golem
# creates a golem that shares with you the life
# it steals and damage it receives
#
# Life: 201
# Attack:  80
# Defense:  120
#
# Current Level: 10
# Converts 126 percent damage to life
# Damage: 24-66
# Mana Cost: 61
#
# Next Level: 11
# Converts 128 percent damage to life
# Damage: 27-72
# Mana Cost: 65
#
# Blood Golem Receives Bonuses From:
# Golem Mastery
# Summon Resist
# Clay Golem: +20 Attack Rating per Level
# Iron Golem: +35 Defense per Level
# Fire Golem: +6% Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Attract
# curses a monster to become the
# target of all nearby monsters
# this curse may not be overridden by another curse
#
# Radius:  6 yards
#
# Current Level: 10
# Duration:  44.4 seconds
# Mana Cost: 17
#
# Next Level: 11
# Duration:  48 seconds
# Mana Cost: 17
#
# ------------------------------------
# ------------------------------------
#
# Decrepify
# curses a group of enemies to make them
# slow, weak and take amplified damage
#
# Radius:  4 yards
#
# Current Level: 10
# Duration: 9.4 seconds
# Mana Cost: 11
#
# Next Level: 11
# Duration: 10 seconds
# Mana Cost: 11
#
# ------------------------------------
# ------------------------------------
#
# Bone Prison
# creates a barrier of fossilized bone around your target
#
# Current Level: 10
# Life: 61
# Duration: 24 seconds
# Mana Cost: 18
#
# Next Level: 11
# Life: 66
# Duration: 24 seconds
# Mana Cost: 17
#
# Bone Prison Receives Bonuses From:
# Bone Armor: +8% Life per Level
# Bone Wall: +8% Life per Level
#
# ------------------------------------
# ------------------------------------
#
# Summon Resist
# passive - increases the resistances
# of all summoned creatures
#
# Current Level: 10
# Resist All:  +57 percent
#
# Next Level: 11
# Resist All:  +59 percent
#
# ------------------------------------
# ------------------------------------
#
# Iron Golem
# transforms a metallic item into a golem that gains
# the properties of the item
#
# Life: 306
# Damage: 7-19
# Attack:  100
# Defense:  490
#
# Current Level: 10
# Thorns damage
# 285  percent damage returned
# Defense Bonus: +350
# Mana Cost: 35
#
# Next Level: 11
# Thorns damage
# 300  percent damage returned
# Defense Bonus: +385
# Mana Cost: 35
#
# Iron Golem Receives Bonuses From:
# Golem Mastery
# Summon Resist
# Clay Golem: +20 Attack Rating per Level
# Blood Golem: +5% Life per Level
# Fire Golem: +6% Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Lower Resist
# curses an enemy to take more damage from all magical attacks
# lowers resistances of monsters
# lowers maximum resistances of hostile players
#
# Current Level: 10
# Radius:  10.6 yards
# Duration: 38 seconds
# Resist All: -55 percent
# Mana Cost: 22
#
# Next Level: 11
# Radius:  11.3 yards
# Duration: 40 seconds
# Resist All: -57 percent
# Mana Cost: 22
#
# ------------------------------------
# ------------------------------------
#
# Poison Nova
# emits an expanding ring of concentrated poison
#
# Current Level: 10
# Poison Damage: 175-215
# over 2 seconds
# Mana Cost: 20
#
# Next Level: 11
# Poison Damage: 193-234
# over 2 seconds
# Mana Cost: 20
#
# Poison Nova Receives Bonuses From:
# Poison Dagger: +10% Poison Damage per Level
# Poison Explosion: +10% Poison Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Bone Spirit
# releases a spirit of the restless undead that
# tracks its target or finds one of its own
#
# Current Level: 10
# Magic Damage: 166-185
# Mana Cost: 16.5
#
# Next Level: 11
# Magic Damage: 183-203
# Mana Cost: 17
#
# Bone Spirit Receives Bonuses From:
# Teeth: +6% Magic Damage per Level
# Bone Wall: +6% Magic Damage per Level
# Bone Spear: +6% Magic Damage per Level
# Bone Prison: +6% Magic Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Fire Golem
# creates a golem that converts the damage
# it receives from fire into life
#
# Life: 313
# Attack:  140
# Defense:  200
#
# Current Level: 10
# Absorbs 76 percent fire damage
# Fire Damage: 187-242
# Holy Fire: 14-16
# Mana Cost: 140
#
# Next Level: 11
# Absorbs 78 percent fire damage
# Fire Damage: 206-262
# Holy Fire: 15-17
# Mana Cost: 150
#
# Fire Golem Receives Bonuses From:
# Golem Mastery
# Summon Resist
# Clay Golem: +20 Attack Rating per Level
# Blood Golem: +5% Life per Level
# Iron Golem: +35 Defense per Level
#
# ------------------------------------
# ------------------------------------
#
# Revive
# returns a monster to life
# to fight by your side
#
# Duration: 180 seconds
# Life:  +200 percent
#
# Current Level: 10
# Monsters:  10
# Mana Cost: 45
#
# Next Level: 11
# Monsters:  11
# Mana Cost: 45
#
# Revive Receives Bonuses From:
# Skeleton Mastery
# Summon Resist
#
# ------------------------------------
# ------------------------------------
#
# Sacrifice
# increased accuracy and damage
# at the cost of life
#
# 8 percent damage to Self
#
# Current Level: 10
# To Attack Rating:  +83 percent
# Damage:  +315 percent
#
# Next Level: 11
# To Attack Rating:  +90 percent
# Damage:  +330 percent
#
# Sacrifice Receives Bonuses From:
# Redemption: +15% Damage per Level
# Fanaticism: +5% Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Smite
# temporarily stun your enemy
# by bashing it with your shield
#
# Current Level: 10
# Damage:  +150 percent
# Stun Length: 10 seconds
# Mana Cost: 2
#
# Next Level: 11
# Damage:  +165 percent
# Stun Length: 10 seconds
# Mana Cost: 2
#
# ------------------------------------
# ------------------------------------
#
# Might
# when active, aura increases the damage
# done by you and your party
#
# Current Level: 10
# Radius:  22.6 yards
# Damage:  +130 percent
#
# Next Level: 11
# Radius:  24 yards
# Damage:  +140 percent
#
# ------------------------------------
# ------------------------------------
#
# Prayer
# when active, aura slowly regenerates
# the life of you and your party
#
# Current Level: 10
# Radius:  22.6 yards
# Heals: +11.0
# Mana Cost: 2.6
#
# Next Level: 11
# Radius:  24 yards
# Heals: +12.0
# Mana Cost: 2.8
#
# ------------------------------------
# ------------------------------------
#
# Resist Fire
# when active, aura decreases fire damage
# done to you and your party
#
# Current Level: 10
# Radius:  22.6 yards
# Resist Fire:  +114 percent
#
# Next Level: 11
# Radius:  24 yards
# Resist Fire:  +116 percent
#
# ------------------------------------
# ------------------------------------
#
# Holy Bolt
# a bolt of divine energy
# that damages undead enemies
# or heals allies
#
# Current Level: 10
# Magic Damage: 84-94
# Heals: 19-42
# Mana Cost: 2.5
#
# Next Level: 11
# Magic Damage: 94-105
# Heals: 21-46
# Mana Cost: 2.6
#
# Holy Bolt Receives Bonuses From:
# Blessed Hammer: +50% Magic Damage per Level
# Fist of the Heavens: +50% Magic Damage per Level
# Prayer: +15% Life Healed per Level
#
# ------------------------------------
# ------------------------------------
#
# Holy Fire
# when active, aura damages nearby enemies
# with heavenly flames
#
# Current Level: 10
# Radius:  10 yards
# Fire Damage: 39-51 to your attack
# Fire Damage: 6.5-8.5
#
# Next Level: 11
# Radius:  10.6 yards
# Fire Damage: 45-57 to your attack
# Fire Damage: 7.5-9.5
#
# Holy Fire Receives Bonuses From:
# Resist Fire: +18% Fire Damage per Level
# Salvation: +6% Fire Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Thorns
# when active, aura reflects damage done to you
# back at your attacker
#
# Current Level: 10
# Radius:  22.6 yards
# 610  percent damage returned
#
# Next Level: 11
# Radius:  24 yards
# 650  percent damage returned
#
# ------------------------------------
# ------------------------------------
#
# Defiance
# when active, aura increases the defense rating
# of you and your party
#
# Current Level: 10
# Radius:  22.6 yards
# Defense Bonus:  +160 percent
#
# Next Level: 11
# Radius:  24 yards
# Defense Bonus:  +170 percent
#
# ------------------------------------
# ------------------------------------
#
# Resist Cold
# when active, aura decreases cold damage
# done to you and your party
#
# Current Level: 10
# Radius:  22.6 yards
# Resist Cold:  +114 percent
#
# Next Level: 11
# Radius:  24 yards
# Resist Cold:  +116 percent
#
# ------------------------------------
# ------------------------------------
#
# Zeal
# allows you to attack multiple adjacent enemies
# with a single attack
#
# Current Level: 10
# Attack Bonus:  +100 percent
# Damage:  +36 percent
# 11  hits
# Mana Cost: 2
#
# Next Level: 11
# Attack Bonus:  +110 percent
# Damage:  +42 percent
# 12  hits
# Mana Cost: 2
#
# Zeal Receives Bonuses From:
# Sacrifice: +12% Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Charge
# charge into battle and attack an enemy
#
# Current Level: 10
# Damage:  +325 percent
# Attack:  +185 percent
# Mana Cost: 9
#
# Next Level: 11
# Damage:  +350 percent
# Attack:  +200 percent
# Mana Cost: 9
#
# Charge Receives Bonuses From:
# Vigor: +20% Damage per Level
# Might: +20% Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Blessed Aim
# when active, aura increases the attack rating
# for you and your party
#
# Current Level: 10
# Radius:  22.6 yards
# Attack:  +210 percent
#
# Next Level: 11
# Radius:  24 yards
# Attack:  +225 percent
#
# ------------------------------------
# ------------------------------------
#
# Cleansing
# when active, aura reduces the length
# of time you and your party
# will remain poisoned or cursed
#
# Current Level: 10
# Radius:  22.6 yards
# Duration reduced by 71 percent
#
# Next Level: 11
# Radius:  24 yards
# Duration reduced by 72 percent
#
# Cleansing Receives Bonuses From:
# Prayer
#
# ------------------------------------
# ------------------------------------
#
# Resist Lightning
# when active, aura decreases lightning damage
# done to you and your party
#
# Current Level: 10
# Radius:  22.6 yards
# Resist Lightning:  +114 percent
#
# Next Level: 11
# Radius:  24 yards
# Resist Lightning:  +116 percent
#
# ------------------------------------
# ------------------------------------
#
# Vengeance
# fire, lightning and cold damage are added
# to each successful attack
#
# Current Level: 10
# Cold Length: 6.6 seconds
# Fire Damage:  +124 percent
# Cold Damage:  +124 percent
# Lightning Damage:  +124 percent
# Attack:  +110 percent
# Mana Cost: 6.2
#
# Next Level: 11
# Cold Length: 7.2 seconds
# Fire Damage:  +130 percent
# Cold Damage:  +130 percent
# Lightning Damage:  +130 percent
# Attack:  +120 percent
# Mana Cost: 6.5
#
# Vengeance Receives Bonuses From:
# Resist Fire: +10% Fire Damage per Level
# Resist Cold: +10% Cold Damage per Level
# Resist Lightning: +10% Lightning Damage per Level
# Salvation: +2% Elemental Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Blessed Hammer
# 150 Percent Damage to Undead
# spirals outwards damaging enemies it hits
# summons an ethereal hammer that
#
# Current Level: 10
# Magic Damage: 88-92
# Mana Cost: 7.2
#
# Next Level: 11
# Magic Damage: 98-102
# Mana Cost: 7.5
#
# Blessed Hammer Receives Bonuses From:
# Blessed Aim: +14% Magic Damage per Level
# Vigor: +14% Magic Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Concentration
# when active, aura increases the damage and decreases the chance
# that the attack will be interrupted for you and your party
#
# Current Level: 10
# Radius:  22.6 yards
# Chance uninterruptable 20 percent
# Damage:  +195 percent
#
# Next Level: 11
# Radius:  24 yards
# Chance uninterruptable 20 percent
# Damage:  +210 percent
#
# ------------------------------------
# ------------------------------------
#
# Holy Freeze
# when active, aura freezes nearby monsters
#
# Current Level: 10
# Radius:  10 yards
# Cold Damage: 65-70 to your attack
# Cold Damage: 13-14
# Enemies slowed 49 percent
#
# Next Level: 11
# Radius:  10.6 yards
# Cold Damage: 75-80 to your attack
# Cold Damage: 15-16
# Enemies slowed 49 percent
#
# Holy Freeze Receives Bonuses From:
# Resist Cold: +15% Cold Damage per Level
# Salvation: +7% Cold Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Vigor
# when active, aura increases stamina recovery rate, maximum stamina
# and movement speed for you and your party
#
# Current Level: 10
# Radius:  28.6 yards
# Velocity:  +36 percent
# Stamina Bonus:  +275 percent
# Stamina Recovery Rate:  +275 percent
#
# Next Level: 11
# Radius:  30.6 yards
# Velocity:  +37 percent
# Stamina Bonus:  +300 percent
# Stamina Recovery Rate:  +300 percent
#
# ------------------------------------
# ------------------------------------
#
# Conversion
# converts monsters to fight against
# other foul demons and beasts
#
# Current Level: 10
# Chance to convert: 34 percent
# Duration: 16 seconds
# Mana Cost: 4
#
# Next Level: 11
# Chance to convert: 35 percent
# Duration: 16 seconds
# Mana Cost: 4
#
# ------------------------------------
# ------------------------------------
#
# Holy Shield
# enhances your shield with divine power
#
# Current Level: 10
# Smite Damage: 23-26
# Duration: 255 seconds
# Defense Bonus:  +160 percent
# Successful Blocking:  +30 percent
# Mana Cost: 35
#
# Next Level: 11
# Smite Damage: 26-29
# Duration: 280 seconds
# Defense Bonus:  +175 percent
# Successful Blocking:  +31 percent
# Mana Cost: 35
#
# Holy Shield Receives Bonuses From:
# Defiance: +15% Defense per Level
#
# ------------------------------------
# ------------------------------------
#
# Holy Shock
# when active, aura causes pulses of electricity
# to damage nearby enemies
# adds lightning damage to your attack
#
# Current Level: 10
# Radius:  10 yards
# Lightning Damage: 1-408 to your attack
# Lightning Damage: 1-68
#
# Next Level: 11
# Radius:  10.6 yards
# Lightning Damage: 1-456 to your attack
# Lightning Damage: 1-76
#
# Holy Shock Receives Bonuses From:
# Resist Lightning: +12% Lightning Damage per Level
# Salvation: +4% Lightning Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Sanctuary
# when active, aura damages the undead
# and knocks them back
#
# Current Level: 10
# Radius:  9.3 yards
# Damage to Undead: +420  percent
# Magic Damage: 44-54
#
# Next Level: 11
# Radius:  10 yards
# Damage to Undead: +450  percent
# Magic Damage: 48-59
#
# Sanctuary Receives Bonuses From:
# Cleansing: +7% Magic Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Meditation
# when active, aura increases mana recovery
# for you and your party
#
# Current Level: 10
# Radius:  22.6 yards
# Mana Recovery Rate:  +525 percent
#
# Next Level: 11
# Radius:  24 yards
# Mana Recovery Rate:  +550 percent
#
# Meditation Receives Bonuses From:
# Prayer
#
# ------------------------------------
# ------------------------------------
#
# Fist of the Heavens
# lightning strikes your target as holy bolts
# seek out nearby enemies
#
# Current Level: 10
# Holy Bolt Damage: 102-112
# Lightning Damage: 315-365
# Mana Cost: 25
#
# Next Level: 11
# Holy Bolt Damage: 112-122
# Lightning Damage: 345-395
# Mana Cost: 25
#
# Fist of the Heavens Receives Bonuses From:
# Holy Bolt: +15% Holy Bolt Damage per Level
# Holy Shock: +7% Lightning Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Fanaticism
# when active, aura increases damage, attack speed,
# and attack rating for you and your party
#
# Current Level: 10
# Radius:  13.3 yards
# Party Damage:  +101 percent
# Your Damage:  +203 percent
# Attack Speed:  +30 percent
# Attack:  +85 percent
#
# Next Level: 11
# Radius:  14 yards
# Party Damage:  +110 percent
# Your Damage:  +220 percent
# Attack Speed:  +31 percent
# Attack:  +90 percent
#
# ------------------------------------
# ------------------------------------
#
# Conviction
# when active, aura reduces the defenses
# and resistances of nearby enemies
#
# Current Level: 10
# Radius:  13.3 yards
# Defense:  -81 percent
# Resistances: -150 percent
#
# Next Level: 11
# Radius:  13.3 yards
# Defense:  -82 percent
# Resistances: -150 percent
#
# ------------------------------------
# ------------------------------------
#
# Redemption
# when active, aura attempts to redeem
# the souls of slain enemies to give
# you life and mana
#
# Current Level: 10
# Radius:  10.6 yards
# Chance to redeem soul: 71 percent
# Life/Mana Recovered: 70 points
#
# Next Level: 11
# Radius:  10.6 yards
# Chance to redeem soul: 74 percent
# Life/Mana Recovered: 75 points
#
# ------------------------------------
# ------------------------------------
#
# Salvation
# when active, aura decreases fire, cold and lightning damage
# done to you and your party
#
# Current Level: 10
# Radius:  22.6 yards
# Resist All:  +98 percent
#
# Next Level: 11
# Radius:  24 yards
# Resist All:  +99 percent
#
# ------------------------------------
# ------------------------------------
#
# Bash
# powerful blow that increases the damage done
# to enemies and knocks them back
#
# Current Level: 10
# Attack:  +65 percent
# Damage:  +95 percent
# Damage: +10
# Mana Cost: 2
#
# Next Level: 11
# Attack:  +70 percent
# Damage:  +100 percent
# Damage: +11
# Mana Cost: 2
#
# Bash Receives Bonuses From:
# Stun: +5% Damage per Level
# Concentrate: +5% Attack Rating per Level
#
# ------------------------------------
# ------------------------------------
#
# Sword Mastery
# passive - improves sword fighting skill
#
# Current Level: 10
# Damage:  +73 percent
# Attack:  +100 percent
# 24 Percent Chance of Critical Strike
#
# Next Level: 11
# Damage:  +78 percent
# Attack:  +108 percent
# 24 Percent Chance of Critical Strike
#
# ------------------------------------
# ------------------------------------
#
# Axe Mastery
# passive - improves axe fighting skill
#
# Current Level: 10
# Damage:  +73 percent
# Attack:  +100 percent
# 24 Percent Chance of Critical Strike
#
# Next Level: 11
# Damage:  +78 percent
# Attack:  +108 percent
# 24 Percent Chance of Critical Strike
#
# ------------------------------------
# ------------------------------------
#
# Mace Mastery
# passive - improves mace fighting skill
#
# Current Level: 10
# Damage:  +73 percent
# Attack:  +100 percent
# 24 Percent Chance of Critical Strike
#
# Next Level: 11
# Damage:  +78 percent
# Attack:  +108 percent
# 24 Percent Chance of Critical Strike
#
# ------------------------------------
# ------------------------------------
#
# Howl
# sends nearby monsters
# ...
#
# Mana Cost: 25
#
# Current Level: 10
# Damage: 30-32
# Fire Damage: 30-32
#
# Next Level: 11
# Damage: 34-36
# Fire Damage: 34-36
#
# Volcano Receives Bonuses From:
# Molten Boulder: +12% Damage per Level
# Fissure: +12% Fire Damage per Level
# Armageddon: +12% Fire Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Tornado
# create a funnel of wind and debris
# to blast your enemies
#
# Mana Cost: 10
#
# Current Level: 10
# Damage: 109-121
#
# Next Level: 11
# Damage: 123-136
#
# Tornado Receives Bonuses From:
# Cyclone Armor: +9% Damage per Level
# Twister: +9% Damage per Level
# Hurricane: +9% Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Spirit of Barbs
# summon spirit pet that reflects damage
# taken by you and your party
# back at your enemies
#
# Current Level: 10
# Life: 692
# 230  percent damage returned
# Radius:  32 yards
# Mana Cost: 34
#
# Next Level: 11
# Life: 745
# 250  percent damage returned
# Radius:  33.3 yards
# Mana Cost: 35
#
# ------------------------------------
# ------------------------------------
#
# Summon Grizzly
# summon a ferocious grizzly bear
#
# Mana Cost: 40
# Life: 812
# Attack:  +25 percent
# Defense:  +40 percent
#
# Current Level: 10
# Damage: 130-160
# Damage:  +115 percent
#
# Next Level: 11
# Damage: 145-175
# Damage:  +125 percent
#
# Summon Grizzly Receives Bonuses From:
# Summon Spirit Wolf
# Summon Dire Wolf
#
# ------------------------------------
# ------------------------------------
#
# Fury
# when in werewolf form, attack
# either multiple adjacent targets
# or one target multiple times
#
# Current Level: 10
# 11  hits
# Attack Bonus:  +113 percent
# Damage:  +253 percent
# Mana Cost: 4
#
# Next Level: 11
# 12  hits
# Attack Bonus:  +120 percent
# Damage:  +270 percent
# Mana Cost: 4
#
# ------------------------------------
# ------------------------------------
#
# Armageddon
# create a meteor shower to rain fiery
# destruction on nearby enemies
#
# Duration: 10 seconds
# Radius:  5.3 yards
# Mana Cost: 35
#
# Current Level: 10
# Average Fire Damage: 77-81 per second
# Fire Damage: 170-231
#
# Next Level: 11
# Average Fire Damage: 85-90 per second
# Fire Damage: 190-253
#
# Armageddon Receives Bonuses From:
# Fissure: +2 Seconds per Level
# Firestorm: +14% Fire Damage per Level
# Molten Boulder: +14% Fire Damage per Level
# Volcano: +14% Fire Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Hurricane
# create a massive storm of wind and
# debris to pound your enemies to bits
#
# Duration: 10 seconds
# Radius:  6 yards
# Mana Cost: 30
#
# Current Level: 10
# Cold Damage: 94-119
#
# Next Level: 11
# Cold Damage: 104-129
#
# Hurricane Receives Bonuses From:
# Cyclone Armor: +2 Seconds per Level
# Twister: +9% Damage per Level
# Tornado: +9% Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Fire Blast
# throw a fire bomb
# to blast your enemies to bits
#
# Radius:  3.3 yards
#
# Current Level: 10
# Fire Damage: 21-32
# Mana Cost: 4.1
#
# Next Level: 11
# Fire Damage: 25-38
# Mana Cost: 4.2
#
# Fire Blast Receives Bonuses From:
# Shock Web: +9% Fire Damage per Level
# Charged Bolt Sentry: +9% Fire Damage per Level
# Wake of Fire: +9% Fire Damage per Level
# Lightning Sentry: +9% Fire Damage per Level
# Wake of Inferno: +9% Fire Damage per Level
# Death Sentry: +9% Fire Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Claw Mastery
# passive - improves your skill
# with claw-class weapons
#
# Current Level: 10
# Damage:  +71 percent
# Attack:  +120 percent
# 17 Percent Chance of Critical Strike
#
# Next Level: 11
# Damage:  +75 percent
# Attack:  +130 percent
# 17 Percent Chance of Critical Strike
#
# ------------------------------------
# ------------------------------------
#
# Psychic Hammer
# use the power of your mind
# to create a psychic blast
# to crush and knock back your enemies
#
# Current Level: 10
# Damage: 11-17
# Magic Damage: 11-17
# Mana Cost: 6.25
#
# Next Level: 11
# Damage: 12-19
# Magic Damage: 12-19
# Mana Cost: 6.5
#
# ------------------------------------
# ------------------------------------
#
# Tiger Strike
#
# Charge-up Skill
#
# consecutive hits add damage bonuses
# to finishing moves
# must use a dragon finishing move or
# normal attack to release charges
#
# Current Level: 10
# Charge 1 -  +280 percent damage
# Charge 2 -  +560 percent damage
# Charge 3 -  +840 percent damage
# Attack:  +78 percent
# Mana Cost: 1
#
# Next Level: 11
# Charge 1 -  +300 percent damage
# Charge 2 -  +600 percent damage
# Charge 3 -  +900 percent damage
# Attack:  +85 percent
# Mana Cost: 1
#
# ------------------------------------
# ------------------------------------
#
# Dragon Talon
#
# Finishing Move
#
# kick your enemies out of your way
# adds charged-up bonuses to the kick
#
# Current Level: 10
# 2 Kicks
# Kick Damage:  +68 percent
# Attack:  +335 percent
# Mana Cost: 6
#
# Next Level: 11
# 2 Kicks
# Kick Damage:  +75 percent
# Attack:  +370 percent
# Mana Cost: 6
#
# ------------------------------------
# ------------------------------------
#
# Shock Web
# throw a web of lightning
# to shock your enemies
#
# Current Level: 10
# Spikes:  8
# Duration: 3.6 seconds
# Lightning Damage: 1-43 per second
# Mana Cost: 6
#
# Next Level: 11
# Spikes:  8
# Duration: 3.6 seconds
# Lightning Damage: 1-49 per second
# Mana Cost: 6
#
# Shock Web Receives Bonuses From:
# Fire Blast: +1 Missile per %d Levels
# Charged Bolt Sentry: +11% Lightning Damage per Level
# Lightning Sentry: +11% Lightning Damage per Level
# Death Sentry: +11% Lightning Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Blade Sentinel
# set a spinning blade to patrol
# between you and target point
#
# Mana Cost: 7
#
# Current Level: 10
# Duration: 8.3 seconds
# Damage: 35-39
# +3/8 Weapon Damage
#
# Next Level: 11
# Duration: 8.8 seconds
# Damage: 39-43
# +3/8 Weapon Damage
#
# ------------------------------------
# ------------------------------------
#
# Burst of Speed
# increases attack and movement speed
# for a period of time
#
# Current Level: 10
# Attack Speed:  +45 percent
# Walk/Run Speed:  +52 percent
# Duration: 228 seconds
# Mana Cost: 10
#
# Next Level: 11
# Attack Speed:  +47 percent
# Walk/Run Speed:  +54 percent
# Duration: 240 seconds
# Mana Cost: 10
#
# ------------------------------------
# ------------------------------------
#
# Fists of Fire
#
# Charge-up Skill
#
# consecutive hits add fire damage
# to finishing moves
# can only be used with claw-class weapons
# must use a dragon finishing move or
# normal attack to release charges
#
# Current Level: 10
# Charge 1 - fire damage:  61-67
# Charge 2 - fire damage radius:  2.6 yards
# Charge 3 - fire damage: 95-101 per second
# Attack:  +78 percent
# Mana Cost: 2
#
# Next Level: 11
# Charge 1 - fire damage:  71-78
# Charge 2 - fire damage radius:  2.6 yards
# Charge 3 - fire damage: 110-117 per second
# Attack:  +85 percent
# Mana Cost: 2
#
# Fists of Fire Receives Bonuses From:
# Phoenix Strike: +12% Fire Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Dragon Claw
#
# Finishing Move
#
# slice and dice your enemies
# with your dual claw-class weapons
# adds charged-up bonuses to both claw attacks
#
# Current Level: 10
# Damage:  +95 percent
# Attack:  +265 percent
# Mana Cost: 2
#
# Next Level: 11
# Damage:  +100 percent
# Attack:  +290 percent
# Mana Cost: 2
#
# Dragon Claw Receives Bonuses From:
# Claw Mastery: +4% Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Charged Bolt Sentry
# a trap that emits charged bolts
# at enemies that pass near
#
# Shoots 5 Times
# Releases 5 charged bolts
# Mana Cost: 13
#
# Current Level: 10
# Lightning Damage: 1-36
#
# Next Level: 11
# Lightning Damage: 1-40
#
# Charged Bolt Sentry Receives Bonuses From:
# Shock Web: +1 Bolt per %d Levels
# Lightning Sentry: +1 Shot per %d Levels
# Fire Blast: +6% Lightning Damage per Level
# Lightning Sentry: +6% Lightning Damage per Level
# Death Sentry: +6% Lightning Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Wake of Fire
# a trap that emits waves of fire
#
# Shoots 5 Times
#
# Current Level: 10
# Fire Damage: 25-30
# Mana Cost: 13
#
# Next Level: 11
# Fire Damage: 28-33
# Mana Cost: 13
#
# Wake of Fire Receives Bonuses From:
# Fire Blast: +8% Fire Damage per Level
# Wake of Inferno: +8% Fire Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Weapon Block
# passive - chance to block when
# you are using dual claw-class weapons
#
# Current Level: 10
# 50  percent chance
#
# Next Level: 11
# 52  percent chance
#
# ------------------------------------
# ------------------------------------
#
# Cloak of Shadows
# cast a shadow to blind nearby enemies
# lowering their defenses for a period of time
#
# Range:  20 yards
# Mana Cost: 13
#
# Current Level: 10
# Duration: 17 seconds
# Defense Bonus:  +37 percent
# Enemy Defense:  -42 percent
#
# Next Level: 11
# Duration: 18 seconds
# Defense Bonus:  +40 percent
# Enemy Defense:  -45 percent
#
# ------------------------------------
# ------------------------------------
#
# Cobra Strike
#
# Charge-up Skill
#
# consecutive hits add life and mana stealing
# to finishing moves
# must use a dragon finishing move or
# normal attack to release charges
#
# Current Level: 10
# Charge 1 -  +85 percent life stealing
# Charge 2 -  +85 percent life and mana stealing
# Charge 3 -  +170 percent life and mana stealing
# Attack:  +78 percent
# Mana Cost: 2
#
# Next Level: 11
# Charge 1 -  +90 percent life stealing
# Charge 2 -  +90 percent life and mana stealing
# Charge 3 -  +180 percent life and mana stealing
# Attack:  +85 percent
# Mana Cost: 2
#
# ------------------------------------
# ------------------------------------
#
# Blade Fury
# throw spinning blades
# to slice up your enemies
#
# Minimum Mana Required to Cast:  3
#
# Current Level: 10
# Damage: 39-41
# +3/4 Weapon Damage
# Mana Cost: 2.1 per blade
#
# Next Level: 11
# Damage: 44-46
# +3/4 Weapon Damage
# Mana Cost: 2.2 per blade
#
# ------------------------------------
# ------------------------------------
#
# Fade
# raise all resistances and resist curses
# for a period of time
#
# Current Level: 10
# Reduces curse duration by 74 percent
# Resist All: 54 percent
# Duration: 228 seconds
# Mana Cost: 10
#
# Next Level: 11
# Reduces curse duration by 75 percent
# Resist All: 56 percent
# Duration: 240 seconds
# Mana Cost: 10
#
# ------------------------------------
# ------------------------------------
#
# Shadow Warrior
# summon a shadow of yourself that mimics
# your skills and fights by your side
#
# Current Level: 10
# Life: 883
# Attack: +400
# Defense Bonus:  +108 percent
# Mana Cost: 31.5
#
# Next Level: 11
# Life: 940
# Attack: +440
# Defense Bonus:  +120 percent
# Mana Cost: 32
#
# ------------------------------------
# ------------------------------------
#
# Claws of Thunder
#
# Charge-up Skill
#
# consecutive hits add lightning damage
# to finishing moves
# can only be used with claw-class weapons
# must use a dragon finishing move or
# normal attack to release charges
#
# Current Level: 10
# Charge 1 - lightning damage:  1-300
# Charge 2 - nova damage: 1-185
# Charge 3 - charged bolt damage: 1-260
# Attack:  +78 percent
# Mana Cost: 4
#
# Next Level: 11
# Charge 1 - lightning damage:  1-340
# Charge 2 - nova damage: 1-210
# Charge 3 - charged bolt damage: 1-300
# Attack:  +85 percent
# Mana Cost: 4
#
# Claws of Thunder Receives Bonuses From:
# Phoenix Strike: +8% Lightning Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Dragon Tail
#
# Finishing Move
#
# knock back your enemies with an explosive kick
# adds charged-up bonuses to the kick
#
# Radius:  4 yards
#
# Current Level: 10
# fire damage:  +140 percent
# Attack:  +155 percent
# Mana Cost: 10
#
# Next Level: 11
# fire damage:  +150 percent
# Attack:  +170 percent
# Mana Cost: 10
#
# ------------------------------------
# ------------------------------------
#
# Lightning Sentry
# a trap that shoots lightning
# to scorch passing enemies
#
# Shoots 10 Times
#
# Current Level: 10
# Lightning Damage: 1-122
# Mana Cost: 20
#
# Next Level: 11
# Lightning Damage: 1-138
# Mana Cost: 20
#
# Lightning Sentry Receives Bonuses From:
# Shock Web: +12% Lightning Damage per Level
# Charged Bolt Sentry: +12% Lightning Damage per Level
# Death Sentry: +12% Lightning Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Wake of Inferno
# trap that sprays fire at passing enemies
#
# Shoots 10 Times
#
# Current Level: 10
# Fire Damage: 94-119
# Mana Cost: 20
#
# Next Level: 11
# Fire Damage: 105-131
# Mana Cost: 20
#
# Wake of Inferno Receives Bonuses From:
# Wake of Fire: +0.5 Yards per Level
# Fire Blast: +10% Fire Damage per Level
# Wake of Fire: +7% Fire Damage per Level
# Death Sentry: +10% Fire Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Mind Blast
# using the power of your mind
# stun a group of enemies
# and convert the feeble-minded
#
# Duration: 6.0-10.0 seconds
# Mana Cost: 15
#
# Current Level: 10
# Damage: 34-44
# Stun Length: 10 seconds
# Chance to convert: 32 percent
#
# Next Level: 11
# Damage: 39-49
# Stun Length: 4 seconds
# Chance to convert: 32 percent
#
# ------------------------------------
# ------------------------------------
#
# Blades of Ice
#
# Charge-up Skill
#
# consecutive hits add cold damage
# to finishing moves
# can only be used with claw-class weapons
# must use a dragon finishing move or
# normal attack to release charges
#
# Current Level: 10
# Charge 1 - cold damage:  91-111
# Charge 2 - cold damage radius:  4 yards
# freeze duration: 7.6 seconds
# Attack:  +78 percent
# Mana Cost: 3
#
# Next Level: 11
# Charge 1 - cold damage:  101-121
# Charge 2 - cold damage radius:  4 yards
# freeze duration: 8 seconds
# Attack:  +85 percent
# Mana Cost: 3
#
# Blades of Ice Receives Bonuses From:
# Phoenix Strike: +8% Cold Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Dragon Flight
#
# Finishing Move
#
# teleport to your enemies
# and destroy them with a kick
# adds charged-up bonuses to the kick
#
# Current Level: 10
# Kick Damage:  +325 percent
# Attack:  +285 percent
# Mana Cost: 15
#
# Next Level: 11
# Kick Damage:  +350 percent
# Attack:  +310 percent
# Mana Cost: 15
#
# ------------------------------------
# ------------------------------------
#
# Death Sentry
# trap that shoots lightning at your enemies
# or explodes nearby corpses laying waste to more enemies
#
# Corpse Explosion Damage: 40-80 percent of corpse Life
# Shoots 5 Times
#
# Current Level: 10
# Radius: 6.3 yards
# Lightning Damage: 1-134
# Mana Cost: 20
#
# Next Level: 11
# Radius: 6.6 yards
# Lightning Damage: 1-148
# Mana Cost: 20
#
# Death Sentry Receives Bonuses From:
# Fire Blast: +1 Shot per %d Levels
# Lightning Sentry: +12% Lightning Damage per Level
#
# ------------------------------------
# ------------------------------------
#
# Blade Shield
# spinning blades slice enemies
# who stray too close
#
# Current Level: 10
# Damage: 48-77
# +1/4 Weapon Damage
# Duration: 65 seconds
# Mana Cost: 45
#
# Next Level: 11
# Damage: 54-83
# +1/4 Weapon Damage
# Duration: 70 seconds
# Mana Cost: 47
#
# ------------------------------------
# ------------------------------------
#
# Venom
# add poison damage to your weapons
#
# Current Level: 10
# Poison Damage: 205-225
# over 0.4 seconds
# Duration: 156 seconds
# Mana Cost: 12
#
# Next Level: 11
# Poison Damage: 225-245
# over 0.4 seconds
# Duration: 160 seconds
# Mana Cost: 12
#
# ------------------------------------
# ------------------------------------
#
# Shadow Master
# summon a powerful shadow of yourself
# to fight by your side
#
# Current Level: 10
# Life: 883
# Attack: +400
# Resist All:  +61 percent
# Mana Cost: 39.5
#
# Next Level: 11
# Life: 940
# Attack: +440
# Resist All:  +63 percent
# Mana Cost: 40
#
# ------------------------------------
# ------------------------------------
#
# Phoenix Strike
#
# Charge-up Skill
#
# adds elemental novas to finishing moves
# must use a dragon finishing move or
# normal attack to release charges
#
# Current Level: 10
# Charge 1 - meteor damage: 128-152
# Fire Explosion Damage: 142-152 per second
# Charge 2 - chain lightning damage: 1-260
# Charge 3 - chaos ice bolt damage: 60-76
# Attack:  +78 percent
# Mana Cost: 4
#
# Next Level: 11
# Charge 1 - meteor damage: 147-173
# Fire Explosion Damage: 166-175 per second
# Charge 2 - chain lightning damage: 1-300
# Charge 3 - chaos ice bolt damage: 68-84
# Attack:  +85 percent
# Mana Cost: 4
#
# Phoenix Strike Receives Bonuses From:
# Fists of Fire: +10% Fire Damage per Level
# Fists of Fire: +6% Average Fire Damage per Second per Level
# Claws of Thunder: +13% Lightning Damage per Level
# Blades of Ice: +10% Cold Damage per Level
#
# ------------------------------------
# ------------------------------------

# %% [markdown]
# ## Look up skills by descline for development

# %%
def select_skills_with_descline(skill_details, pattern):
    skill_names = []
    for skill_name, skill in skill_details.items():
        for descline in skill['descLines']:
            if descline['descLine'] == pattern:
                skill_names.append(skill_name)
                continue
    return skill_names

select_skills_with_descline(skill_details, 31)
# Out:
# ['dimVision', 'confuse', 'attract']
